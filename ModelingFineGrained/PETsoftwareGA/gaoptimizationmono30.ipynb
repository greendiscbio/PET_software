# %% [markdown]
# # Optimization of parameters in genetic algorithms

# %% [markdown]
# This notebook gathers the results for the parameter optimization made on the mono-objective genetic algorithms, considering a binary threshold of 30.

# %% [markdown]
# ### Brief explanation

# %% [markdown]
# With the previous exploration of parameters, we were able to determine which values resulted in better performances. There was obviously not a unique configuration yielding better results so, for the optimization run, we still allowed some variation. We basically assigned different probabilities of appearence to each of the parameters' values. The parameters, their possible values and their associated probabilities are:
#
# - **Estimator**: SVM1 (c=2), SVM2 (c=10), SVM3 (c=50) ------------------------------- Probabilities: 0, 1, 0
# - **Annihilation**: AN1 (0.2), AN2 (0.3), AN3 (0.4) ----------------------------------------- Probabilities: 0, 2/3, 1/3
# - **Elite**: EL1 (0.2), EL2 (0.3), EL3 (0.4) ----------------------------------------------------- Probabilities: 1/4, 1/4, 2/4
# - **Mutation rate**: MR1 (0.05), MR2 (0.1), MR3 (0.15) ---------------------------------- Probabilities: 2/4, 1/4, 1/4
# - **Selection**: SE1 (tournament 2-1) , SE2 (tournament 5-2), SE3 (roulette) ------ Probabilities: 1/3, 1/3, 1/3
#
# For each region, we run 20 models whose parameters are selected according to these probabilities. The best is chosen according to accuracy and f1 score in the test dataset.

# %% [markdown]
# ### Import the packages

# %% [markdown]
# We import the packages that will be needed. In this case, everything is already contained in the gatools.py file, that loads submodules of PyWin module.

# %%
import matplotlib
import seaborn
import sys
sys.path.insert(0,'../../Tools')
from orderedlist import *
from gatools import *
bi = Binarization()
mo = Models()

# %%
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_columns', None)
pandas.set_option('display.width', None)
pandas.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Preparation of results

# %% [markdown]
# #### General stuff

# %%
qual_aal = bi.get_binary(pandas.read_csv('../../Data/Y_aal_quan.csv'),30)
qual_brodmann = bi.get_binary(pandas.read_csv('../../Data/Y_brodmann_quan.csv'),30)

# %%
features = pandas.read_csv('./Optimization_mono_30/optimization_best_features.csv')
features_all = pandas.read_csv('./Optimization_mono_30/optimization_features.csv')
train = pandas.read_csv('./Optimization_mono_30/optimization_best_train.csv')
test = pandas.read_csv('./Optimization_mono_30/optimization_best_test.csv')

# %%
tasks = ['_'.join([i.split('_')[-2],i.split('_')[-1]]) for i in list(features['Model'])]
tasks_brodmann = [i.split('_')[-1] for i in tasks if "b" in i]
tasks_aal = [i for i in tasks if not "b" in i]
tasks_aal.remove('f1mo_l')
tasks_aal.remove('f1mo_r')

# %%
aal_list.remove('f1mo_l')
aal_list.remove('f1mo_r')

# %% [markdown]
# #### Metrics

# %%
pct_aal = round(numpy.divide(numpy.sum(qual_aal),qual_aal.shape[0]).to_frame().transpose(),3)
pct_aal = pct_aal.add_prefix('Region=')
pct_aal.index=['percentage_positive']
pct_brodmann = round(numpy.divide(numpy.sum(qual_brodmann),qual_brodmann.shape[0]).to_frame().transpose(),3)
pct_brodmann = pct_brodmann.add_prefix('Region=')
pct_brodmann.index=['percentage_positive']

# %%
metrics_aal = pandas.DataFrame()
for task in tasks_aal:
    temp_metrics = mo.evaluate_metrics(train,test,task)
    try: metrics_aal = pandas.concat([metrics_aal,temp_metrics],axis=1)
    except: metrics_aal = temp_metrics

# %%
metrics_brodmann = pandas.DataFrame()
for task in tasks_brodmann:
    temp_metrics = mo.evaluate_metrics(train,test,task)
    try: metrics_brodmann = pandas.concat([metrics_brodmann,temp_metrics],axis=1)
    except: metrics_brodmann = temp_metrics

# %% [markdown]
# #### Features

# %%
features_aal = pandas.DataFrame()
for task in tasks_aal:
    temp_features = mo.evaluate_features(features,features_all,task)
    try: features_aal = pandas.concat([features_aal,temp_features],axis=0)
    except: features_aal = temp_features

# %%
features_brodmann = pandas.DataFrame()
for task in tasks_brodmann:
    temp_features = mo.evaluate_features(features,features_all,task)
    try: features_brodmann = pandas.concat([features_brodmann,temp_features],axis=0)
    except: features_brodmann = temp_features

# %%
map_aal = pandas.DataFrame()
for task in aal_list:
    try: 
        temp_map = mo.map_features(features_all,features_list,task)
        try: map_aal = pandas.concat([map_aal,temp_map],axis=0)
        except: map_aal = temp_map
    except: pass

# %%
map_brodmann = pandas.DataFrame()
for task in brodmann_list:
    try: 
        temp_map = mo.map_features(features_all,features_list,task)
        try: map_brodmann = pandas.concat([map_brodmann,temp_map],axis=0)
        except: map_brodmann = temp_map
    except: pass

# %% [markdown]
# ### Results

# %% [markdown]
# #### AAL atlas (90 regions)

# %% [markdown]
# Down below we show the **sorted regions according to accuracy and f1 score**. In the second table, only test information is given (those regions appearing at the top are the ones with better overall models).

# %%
metrics_pct_aal = pandas.concat([metrics_aal,pct_aal],join='inner')
metrics_pct_aal
# Out:
#                        Region=o3_l    Region=t3_l    Region=t2_l  \
# accuracy_test        0.910+/-0.022  0.823+/-0.036  0.827+/-0.045
# accuracy_train       0.987+/-0.005  0.892+/-0.011  0.920+/-0.009
# f1_test              0.691+/-0.069  0.756+/-0.049  0.744+/-0.059
# f1_train             0.957+/-0.015  0.850+/-0.013  0.881+/-0.013
# precision_test       0.712+/-0.096  0.701+/-0.058  0.680+/-0.076
# precision_train      0.918+/-0.027  0.788+/-0.022  0.800+/-0.019
# recall_test          0.688+/-0.110  0.827+/-0.078  0.832+/-0.088
# recall_train         1.000+/-0.000  0.922+/-0.015  0.981+/-0.013
# percentage_positive          0.148          0.331          0.301
#
#                        Region=o3_r  Region=amyg_r  Region=amyg_l  \
# accuracy_test        0.931+/-0.019  0.968+/-0.021  0.984+/-0.012
# accuracy_train       0.995+/-0.003  0.998+/-0.002  0.998+/-0.002
# f1_test              0.649+/-0.108  0.681+/-0.177  0.697+/-0.234
# f1_train             0.977+/-0.013  0.978+/-0.018  0.965+/-0.040
# precision_test       0.769+/-0.154  0.758+/-0.244  0.670+/-0.304
# precision_train      0.955+/-0.025  0.957+/-0.035  0.935+/-0.073
# recall_test          0.599+/-0.163  0.700+/-0.233  0.860+/-0.265
# recall_train         1.000+/-0.000  1.000+/-0.000  1.000+/-0.000
# percentage_positive          0.111          0.048          0.021
#
#                       Region=f2o_r   Region=pcl_r    Region=t2_r  \
# accuracy_test        0.902+/-0.034  0.978+/-0.015  0.766+/-0.036
# accuracy_train       0.944+/-0.007  0.997+/-0.003  0.884+/-0.012
# f1_test              0.661+/-0.101  0.680+/-0.218  0.721+/-0.035
# f1_train             0.800+/-0.021  0.951+/-0.053  0.859+/-0.013
# precision_test       0.563+/-0.116  0.625+/-0.251  0.656+/-0.052
# precision_train      0.681+/-0.029  0.912+/-0.094  0.788+/-0.021
# recall_test          0.820+/-0.115  0.820+/-0.279  0.806+/-0.058
# recall_train         0.970+/-0.021  1.000+/-0.000  0.943+/-0.018
# percentage_positive          0.114          0.027          0.373
#
#                       Region=tha_l    Region=in_l   Region=f3o_l  \
# accuracy_test        0.924+/-0.024  0.896+/-0.028  0.887+/-0.023
# accuracy_train       0.977+/-0.006  0.909+/-0.007  0.959+/-0.007
# f1_test              0.630+/-0.118  0.607+/-0.078  0.602+/-0.070
# f1_train             0.897+/-0.025  0.659+/-0.022  0.849+/-0.023
# precision_test       0.626+/-0.142  0.526+/-0.087  0.535+/-0.078
# precision_train      0.815+/-0.041  0.556+/-0.021  0.769+/-0.038
# recall_test          0.667+/-0.178  0.737+/-0.122  0.710+/-0.131
# recall_train         1.000+/-0.000  0.808+/-0.037  0.950+/-0.015
# percentage_positive          0.099          0.108           0.12
#
#                        Region=t3_r   Region=cau_l    Region=o2_l  \
# accuracy_test        0.767+/-0.036  0.922+/-0.026  0.842+/-0.043
# accuracy_train       0.907+/-0.010  0.938+/-0.010  0.935+/-0.007
# f1_test              0.701+/-0.041  0.600+/-0.106  0.673+/-0.085
# f1_train             0.878+/-0.012  0.695+/-0.033  0.864+/-0.013
# precision_test       0.662+/-0.058  0.542+/-0.150  0.617+/-0.086
# precision_train      0.839+/-0.019  0.589+/-0.055  0.788+/-0.020
# recall_test          0.750+/-0.056  0.711+/-0.145  0.748+/-0.111
# recall_train         0.922+/-0.018  0.858+/-0.049  0.957+/-0.020
# percentage_positive          0.364          0.081          0.217
#
#                      Region=fusi_l   Region=put_l    Region=ag_l  \
# accuracy_test        0.847+/-0.035  0.938+/-0.026  0.805+/-0.035
# accuracy_train       0.981+/-0.005  0.960+/-0.006  0.851+/-0.009
# f1_test              0.643+/-0.070  0.605+/-0.132  0.666+/-0.058
# f1_train             0.956+/-0.012  0.731+/-0.027  0.754+/-0.013
# precision_test       0.630+/-0.102  0.496+/-0.162  0.622+/-0.074
# precision_train      0.928+/-0.019  0.577+/-0.034  0.678+/-0.017
# recall_test          0.670+/-0.096  0.850+/-0.205  0.727+/-0.095
# recall_train         0.986+/-0.008  1.000+/-0.000  0.848+/-0.021
# percentage_positive          0.205          0.054          0.268
#
#                      Region=acin_l    Region=o1_r   Region=f3t_l  \
# accuracy_test        0.866+/-0.017  0.880+/-0.038  0.848+/-0.040
# accuracy_train       0.888+/-0.007  0.958+/-0.009  0.944+/-0.009
# f1_test              0.591+/-0.064  0.637+/-0.107  0.627+/-0.070
# f1_train             0.659+/-0.021  0.879+/-0.023  0.857+/-0.019
# precision_test       0.562+/-0.062  0.596+/-0.109  0.579+/-0.109
# precision_train      0.622+/-0.022  0.784+/-0.037  0.780+/-0.030
# recall_test          0.647+/-0.134  0.704+/-0.161  0.709+/-0.102
# recall_train         0.702+/-0.034  1.000+/-0.000  0.953+/-0.014
# percentage_positive          0.154          0.151          0.178
#
#                        Region=p2_l    Region=o2_r    Region=ag_r  \
# accuracy_test        0.784+/-0.036  0.793+/-0.042  0.795+/-0.042
# accuracy_train       0.834+/-0.013  0.876+/-0.009  0.837+/-0.013
# f1_test              0.667+/-0.061  0.652+/-0.049  0.663+/-0.065
# f1_train             0.747+/-0.016  0.785+/-0.014  0.729+/-0.018
# precision_test       0.642+/-0.061  0.558+/-0.069  0.557+/-0.058
# precision_train      0.708+/-0.028  0.675+/-0.016  0.613+/-0.021
# recall_test          0.706+/-0.100  0.795+/-0.072  0.830+/-0.113
# recall_train         0.793+/-0.026  0.939+/-0.018  0.901+/-0.020
# percentage_positive           0.31          0.241          0.244
#
#                        Region=gr_r  Region=ling_r   Region=tha_r  \
# accuracy_test        0.879+/-0.026  0.896+/-0.031  0.921+/-0.025
# accuracy_train       0.890+/-0.008  0.986+/-0.005  0.990+/-0.004
# f1_test              0.560+/-0.070  0.587+/-0.115  0.558+/-0.128
# f1_train             0.597+/-0.021  0.950+/-0.018  0.946+/-0.023
# precision_test       0.537+/-0.099  0.629+/-0.157  0.560+/-0.130
# precision_train      0.557+/-0.029  0.905+/-0.031  0.898+/-0.042
# recall_test          0.607+/-0.105  0.568+/-0.126  0.580+/-0.173
# recall_train         0.644+/-0.026  1.000+/-0.000  1.000+/-0.000
# percentage_positive          0.127           0.13          0.087
#
#                       Region=f1o_l    Region=in_r   Region=pal_r  \
# accuracy_test        0.872+/-0.029  0.839+/-0.027  0.979+/-0.015
# accuracy_train       0.951+/-0.008  0.852+/-0.014  1.000+/-0.001
# f1_test              0.563+/-0.081  0.559+/-0.050  0.636+/-0.280
# f1_train             0.827+/-0.024  0.580+/-0.028  0.994+/-0.016
# precision_test       0.488+/-0.084  0.490+/-0.057  0.763+/-0.340
# precision_train      0.719+/-0.040  0.515+/-0.035  0.989+/-0.031
# recall_test          0.680+/-0.112  0.663+/-0.090  0.600+/-0.313
# recall_train         0.975+/-0.012  0.667+/-0.032  1.000+/-0.000
# percentage_positive           0.12          0.154          0.036
#
#                       Region=t1p_l    Region=f1_l    Region=o1_l  \
# accuracy_test        0.883+/-0.032  0.815+/-0.034  0.899+/-0.022
# accuracy_train       0.992+/-0.004  0.902+/-0.016  0.985+/-0.005
# f1_test              0.576+/-0.109  0.608+/-0.072  0.540+/-0.100
# f1_train             0.971+/-0.015  0.796+/-0.026  0.934+/-0.020
# precision_test       0.581+/-0.126  0.529+/-0.072  0.545+/-0.099
# precision_train      0.944+/-0.028  0.684+/-0.037  0.877+/-0.035
# recall_test          0.596+/-0.150  0.724+/-0.107  0.558+/-0.149
# recall_train         1.000+/-0.000  0.952+/-0.014  1.000+/-0.000
# percentage_positive          0.136          0.199          0.108
#
#                      Region=acin_r   Region=put_r   Region=f2o_l  \
# accuracy_test        0.860+/-0.027  0.942+/-0.020  0.873+/-0.025
# accuracy_train       0.860+/-0.008  0.992+/-0.004  0.923+/-0.010
# f1_test              0.566+/-0.085  0.532+/-0.143  0.550+/-0.094
# f1_train             0.573+/-0.020  0.934+/-0.028  0.739+/-0.029
# precision_test       0.508+/-0.069  0.519+/-0.154  0.473+/-0.072
# precision_train      0.506+/-0.020  0.878+/-0.048  0.618+/-0.030
# recall_test          0.656+/-0.144  0.580+/-0.185  0.675+/-0.170
# recall_train         0.661+/-0.035  1.000+/-0.000  0.919+/-0.030
# percentage_positive          0.142          0.057          0.117
#
#                       Region=hip_r  Region=fusi_r    Region=gr_l  \
# accuracy_test        0.899+/-0.030  0.766+/-0.038  0.874+/-0.030
# accuracy_train       0.960+/-0.007  0.841+/-0.014  0.884+/-0.014
# f1_test              0.566+/-0.133  0.623+/-0.051  0.544+/-0.089
# f1_train             0.842+/-0.027  0.745+/-0.017  0.576+/-0.036
# precision_test       0.532+/-0.122  0.516+/-0.052  0.491+/-0.120
# precision_train      0.743+/-0.039  0.612+/-0.022  0.509+/-0.046
# recall_test          0.619+/-0.166  0.790+/-0.080  0.635+/-0.121
# recall_train         0.972+/-0.017  0.952+/-0.014  0.667+/-0.031
# percentage_positive          0.108          0.244          0.117
#
#                        Region=oc_l   Region=f1o_r   Region=smg_r  \
# accuracy_test        0.937+/-0.021  0.860+/-0.036  0.832+/-0.043
# accuracy_train       0.990+/-0.004  0.944+/-0.008  0.947+/-0.008
# f1_test              0.544+/-0.163  0.564+/-0.091  0.602+/-0.095
# f1_train             0.937+/-0.024  0.823+/-0.022  0.876+/-0.017
# precision_test       0.580+/-0.165  0.497+/-0.087  0.561+/-0.097
# precision_train      0.883+/-0.043  0.721+/-0.030  0.801+/-0.027
# recall_test          0.540+/-0.208  0.671+/-0.139  0.659+/-0.120
# recall_train         1.000+/-0.000  0.960+/-0.016  0.967+/-0.015
# percentage_positive          0.072          0.136          0.193
#
#                       Region=sma_l   Region=pre_r    Region=p2_r  \
# accuracy_test        0.908+/-0.036  0.810+/-0.025  0.789+/-0.038
# accuracy_train       0.965+/-0.007  0.909+/-0.009  0.913+/-0.012
# f1_test              0.551+/-0.129  0.550+/-0.050  0.587+/-0.065
# f1_train             0.830+/-0.029  0.782+/-0.018  0.834+/-0.019
# precision_test       0.556+/-0.169  0.468+/-0.056  0.533+/-0.070
# precision_train      0.788+/-0.049  0.664+/-0.023  0.736+/-0.029
# recall_test          0.572+/-0.153  0.679+/-0.093  0.664+/-0.101
# recall_train         0.880+/-0.031  0.952+/-0.019  0.963+/-0.014
# percentage_positive          0.096          0.172          0.226
#
#                      Region=f3op_l     Region=q_r   Region=smg_l  \
# accuracy_test        0.855+/-0.032  0.874+/-0.027  0.838+/-0.046
# accuracy_train       0.894+/-0.015  0.952+/-0.010  0.925+/-0.010
# f1_test              0.538+/-0.088  0.520+/-0.097  0.585+/-0.115
# f1_train             0.661+/-0.031  0.819+/-0.032  0.806+/-0.022
# precision_test       0.429+/-0.073  0.449+/-0.084  0.507+/-0.123
# precision_train      0.526+/-0.040  0.694+/-0.046  0.688+/-0.031
# recall_test          0.742+/-0.161  0.637+/-0.163  0.712+/-0.149
# recall_train         0.893+/-0.028  1.000+/-0.000  0.975+/-0.014
# percentage_positive          0.114          0.108           0.16
#
#                        Region=f2_l   Region=pal_l  Region=phip_l  \
# accuracy_test        0.784+/-0.046  0.963+/-0.016  0.881+/-0.026
# accuracy_train       0.929+/-0.011  0.992+/-0.004  0.970+/-0.010
# f1_test              0.603+/-0.080  0.524+/-0.211  0.522+/-0.121
# f1_train             0.871+/-0.018  0.899+/-0.045  0.881+/-0.036
# precision_test       0.564+/-0.084  0.510+/-0.265  0.468+/-0.112
# precision_train      0.801+/-0.028  0.820+/-0.076  0.789+/-0.059
# recall_test          0.658+/-0.113  0.620+/-0.289  0.624+/-0.198
# recall_train         0.956+/-0.015  1.000+/-0.000  1.000+/-0.000
# percentage_positive           0.25          0.036          0.108
#
#                       Region=f3o_r    Region=ro_r   Region=t2p_l  \
# accuracy_test        0.824+/-0.032  0.898+/-0.037  0.872+/-0.036
# accuracy_train       0.827+/-0.009  0.960+/-0.008  0.991+/-0.005
# f1_test              0.530+/-0.067  0.519+/-0.126  0.528+/-0.110
# f1_train             0.535+/-0.018  0.809+/-0.030  0.970+/-0.016
# precision_test       0.515+/-0.082  0.458+/-0.152  0.596+/-0.184
# precision_train      0.513+/-0.025  0.680+/-0.043  0.957+/-0.031
# recall_test          0.556+/-0.089  0.641+/-0.171  0.510+/-0.131
# recall_train         0.559+/-0.021  1.000+/-0.000  0.984+/-0.013
# percentage_positive          0.178          0.084          0.142
#
#                       Region=pre_l    Region=f1_r   Region=f1m_l  \
# accuracy_test        0.821+/-0.037  0.769+/-0.032  0.826+/-0.033
# accuracy_train       0.934+/-0.008  0.829+/-0.011  0.986+/-0.006
# f1_test              0.552+/-0.094  0.564+/-0.059  0.538+/-0.089
# f1_train             0.837+/-0.017  0.676+/-0.015  0.965+/-0.014
# precision_test       0.487+/-0.090  0.501+/-0.061  0.571+/-0.101
# precision_train      0.730+/-0.026  0.598+/-0.023  0.933+/-0.026
# recall_test          0.648+/-0.133  0.656+/-0.104  0.523+/-0.117
# recall_train         0.982+/-0.009  0.779+/-0.024  0.998+/-0.005
# percentage_positive          0.172          0.229          0.196
#
#                       Region=t1p_r    Region=oc_r    Region=pq_r  \
# accuracy_test        0.805+/-0.047  0.873+/-0.026  0.772+/-0.039
# accuracy_train       0.857+/-0.010  0.902+/-0.008  0.878+/-0.014
# f1_test              0.567+/-0.085  0.488+/-0.095  0.565+/-0.059
# f1_train             0.679+/-0.019  0.589+/-0.023  0.763+/-0.023
# precision_test       0.527+/-0.109  0.380+/-0.074  0.483+/-0.059
# precision_train      0.623+/-0.027  0.466+/-0.024  0.656+/-0.031
# recall_test          0.626+/-0.090  0.704+/-0.176  0.695+/-0.106
# recall_train         0.748+/-0.027  0.803+/-0.042  0.913+/-0.026
# percentage_positive          0.202          0.087          0.214
#
#                        Region=f2_r   Region=t2p_r     Region=q_l  \
# accuracy_test        0.746+/-0.047  0.778+/-0.038  0.868+/-0.025
# accuracy_train       0.851+/-0.015  0.898+/-0.010  0.913+/-0.012
# f1_test              0.594+/-0.063  0.563+/-0.074  0.472+/-0.087
# f1_train             0.758+/-0.021  0.803+/-0.016  0.660+/-0.033
# precision_test       0.499+/-0.065  0.483+/-0.064  0.368+/-0.076
# precision_train      0.640+/-0.025  0.681+/-0.024  0.502+/-0.037
# recall_test          0.741+/-0.084  0.683+/-0.109  0.677+/-0.149
# recall_train         0.932+/-0.018  0.978+/-0.014  0.965+/-0.017
# percentage_positive           0.25          0.211          0.087
#
#                      Region=pcin_l    Region=pq_l  Region=ling_l  \
# accuracy_test        0.836+/-0.041  0.766+/-0.038  0.878+/-0.029
# accuracy_train       0.938+/-0.012  0.849+/-0.014  0.953+/-0.009
# f1_test              0.547+/-0.115  0.547+/-0.054  0.482+/-0.111
# f1_train             0.833+/-0.027  0.703+/-0.019  0.805+/-0.030
# precision_test       0.494+/-0.110  0.463+/-0.054  0.414+/-0.099
# precision_train      0.739+/-0.041  0.596+/-0.027  0.675+/-0.043
# recall_test          0.631+/-0.160  0.678+/-0.084  0.596+/-0.161
# recall_train         0.957+/-0.013  0.859+/-0.021  1.000+/-0.000
# percentage_positive           0.16          0.208          0.096
#
#                      Region=mcin_l  Region=mcin_r   Region=hip_l  \
# accuracy_test        0.766+/-0.048  0.754+/-0.039  0.895+/-0.027
# accuracy_train       0.885+/-0.011  0.878+/-0.015  0.952+/-0.009
# f1_test              0.584+/-0.084  0.574+/-0.071  0.469+/-0.123
# f1_train             0.797+/-0.016  0.788+/-0.020  0.757+/-0.033
# precision_test       0.506+/-0.074  0.487+/-0.057  0.398+/-0.110
# precision_train      0.680+/-0.022  0.669+/-0.031  0.632+/-0.052
# recall_test          0.703+/-0.128  0.714+/-0.132  0.612+/-0.204
# recall_train         0.963+/-0.019  0.962+/-0.014  0.950+/-0.029
# percentage_positive          0.235          0.235          0.078
#
#                        Region=p1_l  Region=post_r    Region=v1_r  \
# accuracy_test        0.787+/-0.039  0.848+/-0.036  0.874+/-0.027
# accuracy_train       0.935+/-0.010  0.938+/-0.009  0.958+/-0.009
# f1_test              0.530+/-0.069  0.479+/-0.088  0.453+/-0.104
# f1_train             0.855+/-0.019  0.783+/-0.025  0.822+/-0.031
# precision_test       0.484+/-0.087  0.397+/-0.084  0.412+/-0.108
# precision_train      0.770+/-0.030  0.643+/-0.033  0.714+/-0.049
# recall_test          0.604+/-0.109  0.630+/-0.150  0.537+/-0.164
# recall_train         0.963+/-0.016  1.000+/-0.000  0.970+/-0.015
# percentage_positive          0.199          0.111          0.099
#
#                       Region=hes_l   Region=f1m_r    Region=ro_l  \
# accuracy_test        0.904+/-0.031  0.817+/-0.045  0.914+/-0.028
# accuracy_train       0.951+/-0.008  0.952+/-0.008  0.971+/-0.006
# f1_test              0.454+/-0.133  0.521+/-0.099  0.468+/-0.161
# f1_train             0.689+/-0.035  0.873+/-0.019  0.823+/-0.030
# precision_test       0.338+/-0.112  0.475+/-0.110  0.415+/-0.176
# precision_train      0.527+/-0.042  0.786+/-0.033  0.701+/-0.043
# recall_test          0.723+/-0.210  0.600+/-0.143  0.584+/-0.234
# recall_train         1.000+/-0.000  0.983+/-0.017  1.000+/-0.000
# percentage_positive          0.054          0.166          0.066
#
#                        Region=p1_r    Region=t1_l   Region=cau_r  \
# accuracy_test        0.801+/-0.041  0.747+/-0.032  0.893+/-0.031
# accuracy_train       0.920+/-0.014  0.867+/-0.016  0.896+/-0.013
# f1_test              0.508+/-0.075  0.519+/-0.052  0.464+/-0.147
# f1_train             0.805+/-0.029  0.748+/-0.022  0.482+/-0.043
# precision_test       0.450+/-0.082  0.427+/-0.040  0.413+/-0.127
# precision_train      0.699+/-0.042  0.613+/-0.029  0.417+/-0.045
# recall_test          0.592+/-0.088  0.671+/-0.105  0.568+/-0.234
# recall_train         0.952+/-0.019  0.960+/-0.019  0.574+/-0.061
# percentage_positive          0.172          0.205          0.084
#
#                        Region=t1_r   Region=f3t_r   Region=sma_r  \
# accuracy_test        0.737+/-0.057  0.775+/-0.040  0.885+/-0.030
# accuracy_train       0.837+/-0.019  0.843+/-0.017  0.989+/-0.006
# f1_test              0.574+/-0.077  0.511+/-0.073  0.442+/-0.134
# f1_train             0.737+/-0.024  0.660+/-0.026  0.953+/-0.025
# precision_test       0.492+/-0.077  0.406+/-0.059  0.468+/-0.153
# precision_train      0.624+/-0.032  0.522+/-0.031  0.911+/-0.047
# recall_test          0.698+/-0.100  0.701+/-0.127  0.434+/-0.148
# recall_train         0.901+/-0.027  0.899+/-0.025  1.000+/-0.000
# percentage_positive          0.253          0.169          0.105
#
#                      Region=pcin_r   Region=pcl_l  Region=phip_r  \
# accuracy_test        0.827+/-0.051  0.840+/-0.035  0.761+/-0.041
# accuracy_train       0.906+/-0.010  0.909+/-0.011  0.854+/-0.016
# f1_test              0.493+/-0.106  0.443+/-0.089  0.505+/-0.079
# f1_train             0.724+/-0.023  0.681+/-0.027  0.697+/-0.023
# precision_test       0.404+/-0.097  0.343+/-0.082  0.415+/-0.063
# precision_train      0.578+/-0.028  0.517+/-0.032  0.571+/-0.031
# recall_test          0.654+/-0.148  0.668+/-0.196  0.659+/-0.142
# recall_train         0.973+/-0.024  1.000+/-0.000  0.896+/-0.024
# percentage_positive          0.127          0.096          0.187
#
#                      Region=f3op_r    Region=v1_l   Region=hes_r  \
# accuracy_test        0.788+/-0.038  0.777+/-0.045  0.952+/-0.015
# accuracy_train       0.880+/-0.016  0.834+/-0.016  1.000+/-0.001
# f1_test              0.476+/-0.082  0.453+/-0.070  0.370+/-0.199
# f1_train             0.700+/-0.029  0.585+/-0.026  0.995+/-0.012
# precision_test       0.409+/-0.070  0.333+/-0.055  0.501+/-0.316
# precision_train      0.602+/-0.044  0.429+/-0.024  0.991+/-0.024
# recall_test          0.589+/-0.141  0.729+/-0.145  0.327+/-0.194
# recall_train         0.838+/-0.023  0.922+/-0.036  1.000+/-0.000
# percentage_positive          0.166          0.127          0.048
#
#                      Region=post_l
# accuracy_test        0.813+/-0.047
# accuracy_train       0.918+/-0.011
# f1_test              0.379+/-0.112
# f1_train             0.738+/-0.028
# precision_test       0.332+/-0.131
# precision_train      0.601+/-0.032
# recall_test          0.475+/-0.162
# recall_train         0.959+/-0.021
# percentage_positive           0.12

# %%
metrics_pct_aal.transpose()[['accuracy_test','f1_test','precision_test','recall_test','percentage_positive']]
# Out:
#                accuracy_test        f1_test precision_test    recall_test  \
# Region=o3_l    0.910+/-0.022  0.691+/-0.069  0.712+/-0.096  0.688+/-0.110
# Region=t3_l    0.823+/-0.036  0.756+/-0.049  0.701+/-0.058  0.827+/-0.078
# Region=t2_l    0.827+/-0.045  0.744+/-0.059  0.680+/-0.076  0.832+/-0.088
# Region=o3_r    0.931+/-0.019  0.649+/-0.108  0.769+/-0.154  0.599+/-0.163
# Region=amyg_r  0.968+/-0.021  0.681+/-0.177  0.758+/-0.244  0.700+/-0.233
# Region=amyg_l  0.984+/-0.012  0.697+/-0.234  0.670+/-0.304  0.860+/-0.265
# Region=f2o_r   0.902+/-0.034  0.661+/-0.101  0.563+/-0.116  0.820+/-0.115
# Region=pcl_r   0.978+/-0.015  0.680+/-0.218  0.625+/-0.251  0.820+/-0.279
# Region=t2_r    0.766+/-0.036  0.721+/-0.035  0.656+/-0.052  0.806+/-0.058
# Region=tha_l   0.924+/-0.024  0.630+/-0.118  0.626+/-0.142  0.667+/-0.178
# Region=in_l    0.896+/-0.028  0.607+/-0.078  0.526+/-0.087  0.737+/-0.122
# Region=f3o_l   0.887+/-0.023  0.602+/-0.070  0.535+/-0.078  0.710+/-0.131
# Region=t3_r    0.767+/-0.036  0.701+/-0.041  0.662+/-0.058  0.750+/-0.056
# Region=cau_l   0.922+/-0.026  0.600+/-0.106  0.542+/-0.150  0.711+/-0.145
# Region=o2_l    0.842+/-0.043  0.673+/-0.085  0.617+/-0.086  0.748+/-0.111
# Region=fusi_l  0.847+/-0.035  0.643+/-0.070  0.630+/-0.102  0.670+/-0.096
# Region=put_l   0.938+/-0.026  0.605+/-0.132  0.496+/-0.162  0.850+/-0.205
# Region=ag_l    0.805+/-0.035  0.666+/-0.058  0.622+/-0.074  0.727+/-0.095
# Region=acin_l  0.866+/-0.017  0.591+/-0.064  0.562+/-0.062  0.647+/-0.134
# Region=o1_r    0.880+/-0.038  0.637+/-0.107  0.596+/-0.109  0.704+/-0.161
# Region=f3t_l   0.848+/-0.040  0.627+/-0.070  0.579+/-0.109  0.709+/-0.102
# Region=p2_l    0.784+/-0.036  0.667+/-0.061  0.642+/-0.061  0.706+/-0.100
# Region=o2_r    0.793+/-0.042  0.652+/-0.049  0.558+/-0.069  0.795+/-0.072
# Region=ag_r    0.795+/-0.042  0.663+/-0.065  0.557+/-0.058  0.830+/-0.113
# Region=gr_r    0.879+/-0.026  0.560+/-0.070  0.537+/-0.099  0.607+/-0.105
# Region=ling_r  0.896+/-0.031  0.587+/-0.115  0.629+/-0.157  0.568+/-0.126
# Region=tha_r   0.921+/-0.025  0.558+/-0.128  0.560+/-0.130  0.580+/-0.173
# Region=f1o_l   0.872+/-0.029  0.563+/-0.081  0.488+/-0.084  0.680+/-0.112
# Region=in_r    0.839+/-0.027  0.559+/-0.050  0.490+/-0.057  0.663+/-0.090
# Region=pal_r   0.979+/-0.015  0.636+/-0.280  0.763+/-0.340  0.600+/-0.313
# Region=t1p_l   0.883+/-0.032  0.576+/-0.109  0.581+/-0.126  0.596+/-0.150
# Region=f1_l    0.815+/-0.034  0.608+/-0.072  0.529+/-0.072  0.724+/-0.107
# Region=o1_l    0.899+/-0.022  0.540+/-0.100  0.545+/-0.099  0.558+/-0.149
# Region=acin_r  0.860+/-0.027  0.566+/-0.085  0.508+/-0.069  0.656+/-0.144
# Region=put_r   0.942+/-0.020  0.532+/-0.143  0.519+/-0.154  0.580+/-0.185
# Region=f2o_l   0.873+/-0.025  0.550+/-0.094  0.473+/-0.072  0.675+/-0.170
# Region=hip_r   0.899+/-0.030  0.566+/-0.133  0.532+/-0.122  0.619+/-0.166
# Region=fusi_r  0.766+/-0.038  0.623+/-0.051  0.516+/-0.052  0.790+/-0.080
# Region=gr_l    0.874+/-0.030  0.544+/-0.089  0.491+/-0.120  0.635+/-0.121
# Region=oc_l    0.937+/-0.021  0.544+/-0.163  0.580+/-0.165  0.540+/-0.208
# Region=f1o_r   0.860+/-0.036  0.564+/-0.091  0.497+/-0.087  0.671+/-0.139
# Region=smg_r   0.832+/-0.043  0.602+/-0.095  0.561+/-0.097  0.659+/-0.120
# Region=sma_l   0.908+/-0.036  0.551+/-0.129  0.556+/-0.169  0.572+/-0.153
# Region=pre_r   0.810+/-0.025  0.550+/-0.050  0.468+/-0.056  0.679+/-0.093
# Region=p2_r    0.789+/-0.038  0.587+/-0.065  0.533+/-0.070  0.664+/-0.101
# Region=f3op_l  0.855+/-0.032  0.538+/-0.088  0.429+/-0.073  0.742+/-0.161
# Region=q_r     0.874+/-0.027  0.520+/-0.097  0.449+/-0.084  0.637+/-0.163
# Region=smg_l   0.838+/-0.046  0.585+/-0.115  0.507+/-0.123  0.712+/-0.149
# Region=f2_l    0.784+/-0.046  0.603+/-0.080  0.564+/-0.084  0.658+/-0.113
# Region=pal_l   0.963+/-0.016  0.524+/-0.211  0.510+/-0.265  0.620+/-0.289
# Region=phip_l  0.881+/-0.026  0.522+/-0.121  0.468+/-0.112  0.624+/-0.198
# Region=f3o_r   0.824+/-0.032  0.530+/-0.067  0.515+/-0.082  0.556+/-0.089
# Region=ro_r    0.898+/-0.037  0.519+/-0.126  0.458+/-0.152  0.641+/-0.171
# Region=t2p_l   0.872+/-0.036  0.528+/-0.110  0.596+/-0.184  0.510+/-0.131
# Region=pre_l   0.821+/-0.037  0.552+/-0.094  0.487+/-0.090  0.648+/-0.133
# Region=f1_r    0.769+/-0.032  0.564+/-0.059  0.501+/-0.061  0.656+/-0.104
# Region=f1m_l   0.826+/-0.033  0.538+/-0.089  0.571+/-0.101  0.523+/-0.117
# Region=t1p_r   0.805+/-0.047  0.567+/-0.085  0.527+/-0.109  0.626+/-0.090
# Region=oc_r    0.873+/-0.026  0.488+/-0.095  0.380+/-0.074  0.704+/-0.176
# Region=pq_r    0.772+/-0.039  0.565+/-0.059  0.483+/-0.059  0.695+/-0.106
# Region=f2_r    0.746+/-0.047  0.594+/-0.063  0.499+/-0.065  0.741+/-0.084
# Region=t2p_r   0.778+/-0.038  0.563+/-0.074  0.483+/-0.064  0.683+/-0.109
# Region=q_l     0.868+/-0.025  0.472+/-0.087  0.368+/-0.076  0.677+/-0.149
# Region=pcin_l  0.836+/-0.041  0.547+/-0.115  0.494+/-0.110  0.631+/-0.160
# Region=pq_l    0.766+/-0.038  0.547+/-0.054  0.463+/-0.054  0.678+/-0.084
# Region=ling_l  0.878+/-0.029  0.482+/-0.111  0.414+/-0.099  0.596+/-0.161
# Region=mcin_l  0.766+/-0.048  0.584+/-0.084  0.506+/-0.074  0.703+/-0.128
# Region=mcin_r  0.754+/-0.039  0.574+/-0.071  0.487+/-0.057  0.714+/-0.132
# Region=hip_l   0.895+/-0.027  0.469+/-0.123  0.398+/-0.110  0.612+/-0.204
# Region=p1_l    0.787+/-0.039  0.530+/-0.069  0.484+/-0.087  0.604+/-0.109
# Region=post_r  0.848+/-0.036  0.479+/-0.088  0.397+/-0.084  0.630+/-0.150
# Region=v1_r    0.874+/-0.027  0.453+/-0.104  0.412+/-0.108  0.537+/-0.164
# Region=hes_l   0.904+/-0.031  0.454+/-0.133  0.338+/-0.112  0.723+/-0.210
# Region=f1m_r   0.817+/-0.045  0.521+/-0.099  0.475+/-0.110  0.600+/-0.143
# Region=ro_l    0.914+/-0.028  0.468+/-0.161  0.415+/-0.176  0.584+/-0.234
# Region=p1_r    0.801+/-0.041  0.508+/-0.075  0.450+/-0.082  0.592+/-0.088
# Region=t1_l    0.747+/-0.032  0.519+/-0.052  0.427+/-0.040  0.671+/-0.105
# Region=cau_r   0.893+/-0.031  0.464+/-0.147  0.413+/-0.127  0.568+/-0.234
# Region=t1_r    0.737+/-0.057  0.574+/-0.077  0.492+/-0.077  0.698+/-0.100
# Region=f3t_r   0.775+/-0.040  0.511+/-0.073  0.406+/-0.059  0.701+/-0.127
# Region=sma_r   0.885+/-0.030  0.442+/-0.134  0.468+/-0.153  0.434+/-0.148
# Region=pcin_r  0.827+/-0.051  0.493+/-0.106  0.404+/-0.097  0.654+/-0.148
# Region=pcl_l   0.840+/-0.035  0.443+/-0.089  0.343+/-0.082  0.668+/-0.196
# Region=phip_r  0.761+/-0.041  0.505+/-0.079  0.415+/-0.063  0.659+/-0.142
# Region=f3op_r  0.788+/-0.038  0.476+/-0.082  0.409+/-0.070  0.589+/-0.141
# Region=v1_l    0.777+/-0.045  0.453+/-0.070  0.333+/-0.055  0.729+/-0.145
# Region=hes_r   0.952+/-0.015  0.370+/-0.199  0.501+/-0.316  0.327+/-0.194
# Region=post_l  0.813+/-0.047  0.379+/-0.112  0.332+/-0.131  0.475+/-0.162
#
#               percentage_positive
# Region=o3_l                 0.148
# Region=t3_l                 0.331
# Region=t2_l                 0.301
# Region=o3_r                 0.111
# Region=amyg_r               0.048
# Region=amyg_l               0.021
# Region=f2o_r                0.114
# Region=pcl_r                0.027
# Region=t2_r                 0.373
# Region=tha_l                0.099
# Region=in_l                 0.108
# Region=f3o_l                 0.12
# Region=t3_r                 0.364
# Region=cau_l                0.081
# Region=o2_l                 0.217
# Region=fusi_l               0.205
# Region=put_l                0.054
# Region=ag_l                 0.268
# Region=acin_l               0.154
# Region=o1_r                 0.151
# Region=f3t_l                0.178
# Region=p2_l                  0.31
# Region=o2_r                 0.241
# Region=ag_r                 0.244
# Region=gr_r                 0.127
# Region=ling_r                0.13
# Region=tha_r                0.087
# Region=f1o_l                 0.12
# Region=in_r                 0.154
# Region=pal_r                0.036
# Region=t1p_l                0.136
# Region=f1_l                 0.199
# Region=o1_l                 0.108
# Region=acin_r               0.142
# Region=put_r                0.057
# Region=f2o_l                0.117
# Region=hip_r                0.108
# Region=fusi_r               0.244
# Region=gr_l                 0.117
# Region=oc_l                 0.072
# Region=f1o_r                0.136
# Region=smg_r                0.193
# Region=sma_l                0.096
# Region=pre_r                0.172
# Region=p2_r                 0.226
# Region=f3op_l               0.114
# Region=q_r                  0.108
# Region=smg_l                 0.16
# Region=f2_l                  0.25
# Region=pal_l                0.036
# Region=phip_l               0.108
# Region=f3o_r                0.178
# Region=ro_r                 0.084
# Region=t2p_l                0.142
# Region=pre_l                0.172
# Region=f1_r                 0.229
# Region=f1m_l                0.196
# Region=t1p_r                0.202
# Region=oc_r                 0.087
# Region=pq_r                 0.214
# Region=f2_r                  0.25
# Region=t2p_r                0.211
# Region=q_l                  0.087
# Region=pcin_l                0.16
# Region=pq_l                 0.208
# Region=ling_l               0.096
# Region=mcin_l               0.235
# Region=mcin_r               0.235
# Region=hip_l                0.078
# Region=p1_l                 0.199
# Region=post_r               0.111
# Region=v1_r                 0.099
# Region=hes_l                0.054
# Region=f1m_r                0.166
# Region=ro_l                 0.066
# Region=p1_r                 0.172
# Region=t1_l                 0.205
# Region=cau_r                0.084
# Region=t1_r                 0.253
# Region=f3t_r                0.169
# Region=sma_r                0.105
# Region=pcin_r               0.127
# Region=pcl_l                0.096
# Region=phip_r               0.187
# Region=f3op_r               0.166
# Region=v1_l                 0.127
# Region=hes_r                0.048
# Region=post_l                0.12

# %% [markdown]
# Down below, we include the **selected features for the best model and the most common features in all the models**.

# %%
features_aal
# Out:
#                                                                                                                                                                                                                                                                                                                                            Features best model  \
# Region=o3_l                                                                                      [rocf_copy, rocf_recognition, vospt_decision, tmt_a, mst_indirect, bnt, ace3_language, rocf_time, st_3, rocf_30min, education_years, cbtt_indirect, sdmt, st_1, ace3_fluency, tlt_total_correct, vospt_discrimination, diagnostic_FTD, st_2, fcsrt_dif_total]
# Region=t3_l                                                                                                                                                                                                            [fcsrt_l1, current_age, rocf_30min, education_years, mst_indirect, st_2, fcsrt_dif_total, diagnostic_CT, rocf_recognition, fcsrt_total]
# Region=t2_l                                                                                                                                                                                     [fcsrt_total, education_years, ft_animals, ace3_visuospatial, diagnostic_FTD, diagnostic_AD, rocf_recognition, current_age, st_1, tlt_total_correct, fcsrt_lt]
# Region=o3_r    [vospt_silhouette, rocf_time, diagnostic_FTD, rocf_copy, sex_female, fcsrt_dif_total, rocf_recognition, mst_indirect, st_3, cbtt_direct, current_age, ace, fcsrt_dif_free, vospt_discrimination, rocf_30min, diagnostic_CT, bnt, tlt_total_correct, ace3_attention, cbtt_indirect, st_2, fcsrt_lt, vospt_location, education_years, ft_animals]
# Region=amyg_r                                                                                                                          [current_age, tlt_total_correct, st_1, bnt, mst_indirect, tmt_a, rocf_recognition, sex_male, diagnostic_FTD, vospt_decision, ace3_fluency, vospt_silhouette, fcsrt_dif_total, education_years, fcsrt_total, sex_female]
# Region=amyg_l                                                                                                                                                                                                               [vospt_decision, current_age, vospt_discrimination, st_2, bnt, fcsrt_dif_free, mst_indirect, fcsrt_lt, diagnostic_FTD, rocf_30min]
# Region=f2o_r                                                                                                                                                                                                                                                            [st_3, vospt_decision, ace3_memory, rocf_3min, ft_formal, diagnostic_FTD, current_age]
# Region=pcl_r                                                                                                                                                                                                             [ft_formal, current_age, mst_indirect, rocf_recognition, ace, diagnostic_CT, fcsrt_dif_total, ace3_attention, vospt_silhouette, sdmt]
# Region=t2_r                                                                                                                                                     [rocf_30min, ace3_language, current_age, diagnostic_CT, mst_indirect, sex_male, sex_female, diagnostic_AD, rocf_copy, bnt, diagnostic_FTD, vospt_silhouette, fcsrt_lt, tlt_total_correct, ace]
# Region=tha_l                                                                                                                                                                                                [ace, fcsrt_dif_free, cbtt_direct, st_3, rocf_30min, diagnostic_CT, sex_male, st_1, diagnostic_FTD, vospt_silhouette, ace3_fluency, cbtt_indirect]
# Region=in_l                                                                                                                                                                                                                                                                                               [diagnostic_FTD, st_1, rocf_time, tlt_total_correct]
# Region=f3o_l                                                                                                                                                                                                                         [st_1, st_2, vospt_silhouette, cbtt_indirect, ace3_visuospatial, rocf_copy, tlt_total_correct, ft_formal, diagnostic_FTD]
# Region=t3_r                                                                                                                                                                                     [rocf_recognition, diagnostic_AD, diagnostic_FTD, tmt_a, rocf_30min, ace3_fluency, vospt_silhouette, ace3_language, education_years, tlt_total_correct, tmt_b]
# Region=cau_l                                                                                                                                                                                                                                                                                   [st_2, rocf_recognition, education_years, st_3, diagnostic_FTD]
# Region=o2_l                                                                                                                                                                [diagnostic_AD, st_2, sex_male, rocf_3min, rocf_recognition, fcsrt_total, vospt_location, fcsrt_dif_total, mst_direct, cbtt_direct, diagnostic_FTD, vospt_discrimination, fcsrt_l1]
# Region=fusi_l                                                                                                                              [rocf_recognition, ft_animals, st_3, mst_indirect, rocf_3min, fcsrt_l1, ace3_language, ace3_fluency, sdmt, bnt, fcsrt_lt, diagnostic_FTD, vospt_decision, sex_female, rocf_30min, vospt_discrimination, mst_direct]
# Region=put_l                                                                                                                                                                                          [diagnostic_CT, tlt_total_correct, vospt_decision, education_years, ace3_memory, rocf_30min, rocf_3min, diagnostic_AD, rocf_recognition, diagnostic_FTD]
# Region=ag_l                                                                                                                                                                                                                                                                                 [sex_male, diagnostic_AD, rocf_recognition, st_3, education_years]
# Region=acin_l                                                                                                                                                                                                                                                                                      [rocf_time, fcsrt_dif_free, diagnostic_FTD, vospt_decision]
# Region=o1_r                                                                                        [ace3_visuospatial, rocf_copy, cbtt_direct, rocf_recognition, sex_male, ft_formal, cbtt_indirect, diagnostic_CT, diagnostic_AD, fcsrt_dif_total, fcsrt_dif_free, rocf_time, tmt_b, diagnostic_FTD, st_2, vospt_discrimination, sex_female, bnt, mst_direct]
# Region=f3t_l                                                                                                                                                                                                           [fcsrt_lt, mst_direct, fcsrt_l1, diagnostic_CT, education_years, rocf_recognition, mst_indirect, diagnostic_AD, ft_formal, tmt_b, st_1]
# Region=p2_l                                                                                                                                                                                                                                                                       [ft_formal, diagnostic_AD, tmt_a, education_years, ace3_fluency, ft_animals]
# Region=o2_r                                                                                                                                                                                                                  [rocf_recognition, cbtt_direct, vospt_silhouette, bnt, rocf_30min, fcsrt_dif_total, diagnostic_AD, ace3_language, vospt_decision]
# Region=ag_r                                                                                                                                                                                                                                                     [ace, rocf_copy, cbtt_indirect, vospt_location, vospt_decision, diagnostic_AD, ace3_attention]
# Region=gr_r                                                                                                                                                                                                                                                                                                             [fcsrt_dif_free, st_3, diagnostic_FTD]
# Region=ling_r                                                                                        [vospt_location, tmt_b, rocf_30min, vospt_discrimination, mst_direct, fcsrt_total, fcsrt_lt, rocf_time, fcsrt_dif_total, fcsrt_l1, sex_male, tmt_a, diagnostic_CT, ft_formal, rocf_3min, ace, diagnostic_AD, ace3_fluency, mst_indirect, education_years]
# Region=tha_r                                                                                                                                                                                              [diagnostic_FTD, sex_female, vospt_silhouette, rocf_time, mst_indirect, fcsrt_l1, current_age, ace, rocf_30min, st_2, ace3_memory, ft_animals, st_1]
# Region=f1o_l                                                                                                                                                                                                                                   [education_years, diagnostic_FTD, cbtt_direct, tlt_total_correct, ace3_language, vospt_silhouette, current_age]
# Region=in_r                                                                                                                                                                                                                                                         [diagnostic_FTD, diagnostic_AD, diagnostic_CT, tmt_b, tlt_total_correct, vospt_silhouette]
# Region=pal_r                                                                                                                                                                    [st_1, rocf_3min, cbtt_indirect, rocf_30min, fcsrt_total, mst_indirect, mst_direct, current_age, education_years, diagnostic_FTD, ft_animals, diagnostic_CT, vospt_silhouette]
# Region=t1p_l                                                                                                        [st_2, rocf_time, ft_animals, vospt_discrimination, bnt, sex_female, fcsrt_dif_total, mst_indirect, fcsrt_total, fcsrt_dif_free, sdmt, current_age, cbtt_indirect, diagnostic_FTD, ft_formal, diagnostic_AD, tmt_a, rocf_30min, rocf_copy]
# Region=f1_l                                                                                                                                                                                              [rocf_copy, diagnostic_AD, rocf_30min, rocf_recognition, ace3_attention, fcsrt_l1, current_age, fcsrt_dif_free, diagnostic_FTD, tmt_b, diagnostic_CT]
# Region=o1_l                                                                                                                                                   [ace3_attention, tmt_b, fcsrt_total, rocf_recognition, cbtt_indirect, mst_indirect, vospt_silhouette, current_age, fcsrt_dif_free, sdmt, tmt_a, st_3, cbtt_direct, diagnostic_AD, bnt, sex_male]
# Region=acin_r                                                                                                                                                                                                                                                                                         [education_years, diagnostic_FTD, fcsrt_dif_total, st_2]
# Region=put_r                                                                                                                                                                                                                                    [cbtt_indirect, ace3_fluency, tlt_total_correct, tmt_a, current_age, fcsrt_total, ace, vospt_silhouette, st_1]
# Region=f2o_l                                                                                                                                                                                                                                                       [st_1, st_2, bnt, mst_direct, current_age, mst_indirect, diagnostic_FTD, tlt_total_correct]
# Region=hip_r                                                                                                                    [ft_formal, ace3_language, cbtt_indirect, ace3_fluency, current_age, rocf_30min, diagnostic_AD, ace, fcsrt_total, fcsrt_dif_total, sdmt, bnt, sex_female, st_1, sex_male, ace3_attention, st_2, diagnostic_CT, fcsrt_dif_free]
# Region=fusi_r                                                                                                                                                                                                        [diagnostic_CT, diagnostic_FTD, diagnostic_AD, current_age, fcsrt_total, ace3_visuospatial, vospt_location, fcsrt_l1, fcsrt_lt, sex_male]
# Region=gr_l                                                                                                                                                                                                                                                                                                   [fcsrt_dif_free, fcsrt_lt, st_2, diagnostic_FTD]
# Region=oc_l                                                                                                                      [cbtt_direct, ft_formal, bnt, diagnostic_CT, diagnostic_FTD, rocf_30min, fcsrt_total, fcsrt_dif_free, sdmt, ace3_language, vospt_location, current_age, tlt_total_correct, sex_female, vospt_decision, st_3, tmt_b, sex_male]
# Region=f1o_r                                                                                                                                                                                                                            [fcsrt_l1, ace3_language, current_age, st_1, diagnostic_FTD, tmt_a, vospt_decision, tlt_total_correct, fcsrt_dif_free]
# Region=smg_r                                                                                                                                                  [vospt_silhouette, ace3_language, cbtt_indirect, mst_direct, ace3_visuospatial, tlt_total_correct, rocf_recognition, fcsrt_dif_total, diagnostic_AD, ft_animals, current_age, fcsrt_total, st_2]
# Region=sma_l                                                                                                                                                                                                                          [rocf_3min, tlt_total_correct, mst_direct, education_years, diagnostic_FTD, diagnostic_CT, rocf_30min, rocf_recognition]
# Region=pre_r                                                                                                                                                                                                             [ft_formal, diagnostic_FTD, ace3_fluency, sex_male, current_age, fcsrt_l1, tmt_a, cbtt_indirect, sex_female, mst_indirect, rocf_copy]
# Region=p2_r                                                                                                                                                                                                                   [fcsrt_dif_free, mst_direct, vospt_discrimination, fcsrt_lt, tmt_b, diagnostic_AD, rocf_copy, ft_formal, st_3, rocf_recognition]
# Region=f3op_l                                                                                                                                                                                                                                                                                 [ace3_memory, diagnostic_FTD, fcsrt_dif_total, rocf_30min, st_3]
# Region=q_r                                                                                                                                                       [st_2, fcsrt_lt, vospt_discrimination, bnt, fcsrt_total, current_age, diagnostic_CT, tmt_a, fcsrt_dif_total, sex_female, rocf_30min, diagnostic_FTD, vospt_silhouette, mst_direct, rocf_copy]
# Region=smg_l                                                                                                                                                                                                                              [fcsrt_dif_total, st_3, rocf_time, vospt_discrimination, cbtt_direct, sex_male, fcsrt_dif_free, tmt_b, mst_indirect]
# Region=f2_l                                                                                                                                                                   [fcsrt_dif_free, fcsrt_l1, diagnostic_AD, ft_formal, ace3_visuospatial, ace3_memory, tmt_a, diagnostic_CT, education_years, rocf_3min, sex_female, sdmt, fcsrt_total, rocf_copy]
# Region=pal_l                                                                                                                                                       [current_age, education_years, ft_animals, tlt_total_correct, ace3_memory, fcsrt_lt, ace, vospt_decision, diagnostic_FTD, tmt_b, fcsrt_total, ft_formal, st_2, diagnostic_AD, ace3_fluency]
# Region=phip_l                                                                                                                                            [vospt_silhouette, education_years, diagnostic_CT, fcsrt_dif_free, cbtt_indirect, diagnostic_FTD, fcsrt_lt, sex_female, vospt_decision, vospt_discrimination, vospt_location, tmt_a, fcsrt_dif_total]
# Region=f3o_r                                                                                                                                                                                                                                                                                           [fcsrt_dif_total, diagnostic_FTD, vospt_discrimination]
# Region=ro_r                                                                                                                                                                                                                 [fcsrt_lt, fcsrt_dif_free, ace3_fluency, rocf_recognition, vospt_location, rocf_copy, tmt_b, st_1, fcsrt_total, ace3_visuospatial]
# Region=t2p_l                                [rocf_3min, fcsrt_total, rocf_recognition, ace3_language, fcsrt_lt, diagnostic_CT, st_2, ace3_fluency, mst_direct, sex_male, st_1, sex_female, vospt_discrimination, tlt_total_correct, diagnostic_AD, diagnostic_FTD, bnt, rocf_30min, st_3, fcsrt_dif_free, vospt_decision, ace3_memory, tmt_b, education_years]
# Region=pre_l                                                                                                                                                                                             [rocf_recognition, education_years, tmt_b, rocf_copy, diagnostic_CT, ace3_visuospatial, sex_male, tmt_a, sdmt, cbtt_indirect, mst_direct, ft_animals]
# Region=f1_r                                                                                                                                                                                                                                                                       [diagnostic_FTD, cbtt_indirect, current_age, cbtt_direct, tlt_total_correct]
# Region=f1m_l                                                                                                                                        [vospt_discrimination, current_age, ft_animals, mst_indirect, tmt_b, rocf_recognition, fcsrt_dif_free, vospt_silhouette, fcsrt_total, education_years, diagnostic_FTD, rocf_30min, ace3_memory, rocf_copy]
# Region=t1p_r                                                                                                                                                                                                                                                                     [ace3_language, fcsrt_lt, diagnostic_FTD, sex_female, st_3, vospt_silhouette]
# Region=oc_r                                                                                                                                                                                                                                                                      [fcsrt_lt, st_1, diagnostic_FTD, fcsrt_dif_total, sex_female, fcsrt_dif_free]
# Region=pq_r                                                                                                                                                                                                                                                             [bnt, sdmt, current_age, diagnostic_AD, rocf_recognition, rocf_3min, vospt_silhouette]
# Region=f2_r                                                                                                                                                                                                                                                 [fcsrt_total, fcsrt_lt, tlt_total_correct, ft_animals, vospt_location, current_age, sex_male, ace]
# Region=t2p_r                                                                                                                                                                                                       [ace3_visuospatial, current_age, st_1, rocf_30min, fcsrt_total, diagnostic_FTD, diagnostic_CT, sdmt, tmt_b, rocf_copy, rocf_3min, sex_male]
# Region=q_l                                                                                                                                                                                                                        [rocf_3min, vospt_location, vospt_discrimination, ft_animals, diagnostic_CT, diagnostic_AD, ace3_fluency, tlt_total_correct]
# Region=pcin_l                                                                                                                                                                                  [st_1, vospt_decision, cbtt_indirect, diagnostic_AD, ft_animals, vospt_discrimination, bnt, diagnostic_FTD, rocf_time, vospt_location, fcsrt_lt, ace3_language]
# Region=pq_l                                                                                                                                                                                                                                                               [st_3, diagnostic_FTD, rocf_recognition, vospt_discrimination, fcsrt_lt, mst_direct]
# Region=ling_l                                                                                                                                                                        [ft_animals, rocf_30min, diagnostic_CT, diagnostic_AD, st_2, vospt_discrimination, tmt_b, vospt_location, sex_male, fcsrt_lt, rocf_3min, rocf_recognition, ace, fcsrt_l1]
# Region=mcin_l                                                                                                                                                                                                                     [tmt_b, vospt_decision, education_years, current_age, vospt_location, diagnostic_CT, st_1, rocf_3min, st_2, fcsrt_dif_total]
# Region=mcin_r                                                                                                                                                                                                             [rocf_copy, tlt_total_correct, st_1, diagnostic_CT, ft_formal, rocf_3min, diagnostic_FTD, current_age, mst_indirect, fcsrt_dif_free]
# Region=hip_l                                                                                                                                                                                                         [tmt_b, diagnostic_AD, fcsrt_dif_free, rocf_recognition, current_age, rocf_30min, education_years, diagnostic_FTD, st_3, fcsrt_dif_total]
# Region=p1_l                                                                                                                                                                                           [fcsrt_total, ace3_language, st_1, mst_direct, rocf_3min, current_age, diagnostic_CT, ft_formal, diagnostic_FTD, tmt_a, fcsrt_dif_free, education_years]
# Region=post_r                                                                                                                                                                                         [vospt_discrimination, sex_female, rocf_copy, sex_male, fcsrt_l1, st_1, fcsrt_lt, st_2, vospt_decision, fcsrt_total, ace3_memory, rocf_30min, ft_formal]
# Region=v1_r                                                                                                                                                                                                [tmt_a, mst_indirect, fcsrt_total, rocf_30min, fcsrt_dif_free, fcsrt_l1, ace3_fluency, vospt_discrimination, rocf_time, current_age, diagnostic_CT]
# Region=hes_l                                                                                                                                                                                                                                 [ace, fcsrt_dif_total, diagnostic_FTD, rocf_recognition, education_years, vospt_silhouette, tmt_b, diagnostic_CT]
# Region=f1m_r                                                                                                                                                                                                          [st_3, diagnostic_FTD, bnt, fcsrt_dif_free, tmt_b, ft_animals, mst_indirect, current_age, cbtt_indirect, education_years, diagnostic_CT]
# Region=ro_l                                                                                                                                                                                                        [rocf_30min, diagnostic_CT, vospt_silhouette, ace3_language, tmt_a, fcsrt_total, sex_male, ace3_fluency, ace, education_years, ace3_memory]
# Region=p1_r                                                                                                                                                                                                         [ft_animals, fcsrt_total, diagnostic_CT, sdmt, rocf_30min, rocf_copy, fcsrt_dif_free, rocf_recognition, ace, fcsrt_dif_total, cbtt_direct]
# Region=t1_l                                                                                                                                                                                                                     [vospt_silhouette, fcsrt_dif_free, fcsrt_total, cbtt_direct, ft_animals, ace3_fluency, diagnostic_CT, ft_formal, mst_indirect]
# Region=cau_r                                                                                                                                                                                                                                                                                          [rocf_recognition, diagnostic_FTD, sex_male, sex_female]
# Region=t1_r                                                                                                                                                                                                                                             [cbtt_indirect, fcsrt_lt, vospt_location, tmt_b, rocf_3min, diagnostic_AD, ace3_attention, rocf_30min]
# Region=f3t_r                                                                                                                                                                                                                                                           [st_2, fcsrt_dif_total, diagnostic_FTD, rocf_3min, current_age, mst_indirect, fcsrt_lt]
# Region=sma_r                                                                                                      [st_3, tmt_b, diagnostic_AD, rocf_30min, vospt_silhouette, diagnostic_CT, st_1, diagnostic_FTD, ace3_visuospatial, tlt_total_correct, ace3_fluency, ft_formal, bnt, education_years, fcsrt_lt, sdmt, fcsrt_l1, ace3_memory, ace, mst_direct]
# Region=pcin_r                                                                                                                                                                                                                                     [education_years, rocf_3min, sex_female, vospt_silhouette, rocf_recognition, diagnostic_AD, rocf_time, st_3]
# Region=pcl_l                                                                                                                                                                                                                                                           [fcsrt_dif_free, rocf_copy, ace3_attention, mst_direct, current_age, tlt_total_correct]
# Region=phip_r                                                                                                                                                                                                                                                              [cbtt_indirect, diagnostic_FTD, ft_animals, education_years, current_age, fcsrt_l1]
# Region=f3op_r                                                                                                                                                                                                                                                             [rocf_recognition, sdmt, fcsrt_lt, diagnostic_FTD, rocf_30min, cbtt_indirect, tmt_a]
# Region=v1_l                                                                                                                                                                                                                                                                                [sex_male, fcsrt_lt, st_2, tmt_a, vospt_discrimination, rocf_30min]
# Region=hes_r                                                                             [diagnostic_FTD, bnt, diagnostic_AD, ft_formal, fcsrt_lt, education_years, ace3_visuospatial, cbtt_indirect, mst_indirect, vospt_silhouette, rocf_recognition, tlt_total_correct, st_1, fcsrt_l1, fcsrt_dif_free, ace, sex_male, sex_female, mst_direct, ace3_memory]
# Region=post_l                                                                                                                                                                                                                    [current_age, diagnostic_CT, mst_direct, fcsrt_lt, cbtt_indirect, rocf_3min, st_2, st_3, fcsrt_dif_free, ace3_language, st_1]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Features all models  \
# Region=o3_l                                                       [(st_1, 1.0), (rocf_recognition, 1.0), (vospt_discrimination, 1.0), (st_3, 0.95), (diagnostic_FTD, 0.85), (education_years, 0.85), (rocf_3min, 0.7), (tmt_a, 0.6), (mst_direct, 0.6), (fcsrt_dif_total, 0.6), (ace3_fluency, 0.6), (cbtt_indirect, 0.55), (sdmt, 0.55), (tlt_total_correct, 0.55), (ace3_language, 0.55), (mst_indirect, 0.5), (rocf_copy, 0.5), (rocf_30min, 0.5), (ft_animals, 0.45), (bnt, 0.45), (st_2, 0.4), (vospt_decision, 0.4), (current_age, 0.4), (fcsrt_dif_free, 0.35), (ace3_visuospatial, 0.35), (cbtt_direct, 0.35), (fcsrt_lt, 0.3), (ace3_attention, 0.25), (tmt_b, 0.25), (diagnostic_AD, 0.25), (diagnostic_CT, 0.25), (rocf_time, 0.2), (fcsrt_l1, 0.15), (vospt_location, 0.15), (ft_formal, 0.15), (ace, 0.1), (fcsrt_total, 0.1), (ace3_memory, 0.1), (sex_male, 0.05)]
# Region=t3_l                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [(rocf_recognition, 1.0), (current_age, 1.0), (rocf_30min, 1.0), (diagnostic_CT, 1.0), (education_years, 1.0), (fcsrt_l1, 0.95), (fcsrt_dif_total, 0.9), (fcsrt_lt, 0.6), (fcsrt_total, 0.45), (mst_indirect, 0.4), (ace3_visuospatial, 0.4), (st_2, 0.25), (st_1, 0.25), (sdmt, 0.2), (fcsrt_dif_free, 0.15), (ace3_attention, 0.15), (ace3_language, 0.1), (rocf_3min, 0.05), (bnt, 0.05)]
# Region=t2_l                                                                                                                                                                                                                                                                                                                                                  [(education_years, 1.0), (st_1, 1.0), (ace3_visuospatial, 0.95), (rocf_recognition, 0.9), (diagnostic_AD, 0.85), (fcsrt_lt, 0.75), (diagnostic_CT, 0.65), (fcsrt_dif_total, 0.65), (diagnostic_FTD, 0.55), (current_age, 0.55), (ft_animals, 0.4), (tlt_total_correct, 0.4), (ace3_fluency, 0.4), (st_2, 0.35), (fcsrt_total, 0.35), (vospt_silhouette, 0.2), (rocf_30min, 0.2), (st_3, 0.2), (cbtt_indirect, 0.1), (ace3_attention, 0.05), (tmt_b, 0.05), (ace3_language, 0.05), (cbtt_direct, 0.05), (sdmt, 0.05)]
# Region=o3_r     [(rocf_recognition, 1.0), (education_years, 0.95), (cbtt_indirect, 0.95), (ace3_attention, 0.95), (cbtt_direct, 0.95), (vospt_location, 0.95), (rocf_copy, 0.85), (tlt_total_correct, 0.85), (ace3_visuospatial, 0.85), (diagnostic_FTD, 0.8), (diagnostic_AD, 0.8), (bnt, 0.8), (ace, 0.75), (vospt_silhouette, 0.75), (current_age, 0.75), (diagnostic_CT, 0.75), (rocf_30min, 0.75), (st_2, 0.75), (rocf_3min, 0.75), (vospt_discrimination, 0.7), (ace3_fluency, 0.7), (ace3_memory, 0.7), (sdmt, 0.65), (st_3, 0.65), (fcsrt_l1, 0.65), (fcsrt_dif_total, 0.65), (mst_indirect, 0.6), (sex_male, 0.6), (fcsrt_lt, 0.6), (tmt_b, 0.6), (ft_animals, 0.55), (fcsrt_dif_free, 0.55), (fcsrt_total, 0.5), (mst_direct, 0.5), (ace3_language, 0.45), (ft_formal, 0.45), (rocf_time, 0.45), (sex_female, 0.45), (vospt_decision, 0.4), (st_1, 0.3), (tmt_a, 0.25)]
# Region=amyg_r                            [(current_age, 1.0), (fcsrt_total, 0.95), (vospt_silhouette, 0.95), (ace3_fluency, 0.95), (vospt_decision, 0.95), (st_1, 0.9), (rocf_30min, 0.85), (fcsrt_dif_total, 0.8), (diagnostic_FTD, 0.75), (sex_male, 0.7), (mst_indirect, 0.7), (ft_formal, 0.65), (diagnostic_CT, 0.65), (sex_female, 0.65), (diagnostic_AD, 0.6), (tmt_a, 0.55), (tlt_total_correct, 0.5), (bnt, 0.5), (ft_animals, 0.45), (rocf_recognition, 0.45), (st_2, 0.45), (rocf_3min, 0.4), (rocf_copy, 0.4), (ace3_language, 0.4), (ace, 0.35), (rocf_time, 0.35), (vospt_discrimination, 0.35), (tmt_b, 0.3), (fcsrt_dif_free, 0.25), (ace3_visuospatial, 0.25), (education_years, 0.2), (mst_direct, 0.2), (st_3, 0.2), (ace3_attention, 0.2), (fcsrt_l1, 0.15), (ace3_memory, 0.15), (fcsrt_lt, 0.15), (cbtt_direct, 0.15), (sdmt, 0.05), (cbtt_indirect, 0.05)]
# Region=amyg_l                                                                                                                          [(rocf_30min, 0.95), (st_1, 0.9), (diagnostic_FTD, 0.85), (current_age, 0.85), (fcsrt_dif_free, 0.8), (education_years, 0.75), (sex_female, 0.75), (vospt_decision, 0.7), (fcsrt_lt, 0.7), (vospt_discrimination, 0.7), (ft_formal, 0.7), (bnt, 0.6), (rocf_copy, 0.6), (sex_male, 0.55), (rocf_recognition, 0.5), (st_2, 0.45), (mst_indirect, 0.45), (diagnostic_AD, 0.35), (st_3, 0.35), (fcsrt_dif_total, 0.35), (diagnostic_CT, 0.3), (rocf_3min, 0.25), (vospt_location, 0.25), (mst_direct, 0.25), (tmt_a, 0.25), (ace3_visuospatial, 0.2), (tmt_b, 0.1), (fcsrt_l1, 0.1), (vospt_silhouette, 0.1), (fcsrt_total, 0.1), (ace3_fluency, 0.05), (ft_animals, 0.05), (ace3_attention, 0.05), (rocf_time, 0.05), (ace3_language, 0.05)]
# Region=f2o_r                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [(rocf_3min, 1.0), (ace3_memory, 1.0), (current_age, 1.0), (st_3, 1.0), (diagnostic_FTD, 1.0), (ft_formal, 0.95), (vospt_decision, 0.6), (st_2, 0.15), (ace, 0.15), (bnt, 0.1), (ace3_visuospatial, 0.05), (tmt_a, 0.05), (diagnostic_CT, 0.05), (ace3_attention, 0.05), (fcsrt_lt, 0.05), (vospt_silhouette, 0.05), (diagnostic_AD, 0.05), (cbtt_direct, 0.05)]
# Region=pcl_r                                                                                                                                                                                                                                                                                                                                                [(rocf_recognition, 0.95), (sdmt, 0.95), (vospt_silhouette, 0.9), (fcsrt_dif_total, 0.85), (diagnostic_CT, 0.8), (current_age, 0.8), (mst_indirect, 0.75), (rocf_copy, 0.7), (vospt_decision, 0.7), (ace3_attention, 0.5), (vospt_discrimination, 0.45), (ace3_visuospatial, 0.4), (ace3_language, 0.35), (ace, 0.35), (rocf_time, 0.25), (ft_formal, 0.25), (st_2, 0.25), (ft_animals, 0.2), (tmt_a, 0.15), (fcsrt_dif_free, 0.15), (ace3_memory, 0.05), (ace3_fluency, 0.05), (rocf_30min, 0.05), (fcsrt_lt, 0.05)]
# Region=t2_r                                                                                                                                                                         [(diagnostic_CT, 1.0), (ace3_language, 1.0), (rocf_30min, 0.95), (fcsrt_lt, 0.85), (rocf_copy, 0.8), (sex_female, 0.75), (mst_indirect, 0.75), (current_age, 0.7), (ace3_fluency, 0.55), (tlt_total_correct, 0.5), (sex_male, 0.5), (st_2, 0.5), (diagnostic_AD, 0.5), (vospt_silhouette, 0.45), (ace3_visuospatial, 0.35), (rocf_3min, 0.3), (diagnostic_FTD, 0.25), (st_3, 0.25), (bnt, 0.25), (ace, 0.2), (sdmt, 0.2), (rocf_recognition, 0.15), (tmt_a, 0.1), (ace3_memory, 0.1), (ace3_attention, 0.1), (mst_direct, 0.05), (tmt_b, 0.05), (fcsrt_dif_free, 0.05), (vospt_decision, 0.05), (fcsrt_total, 0.05), (fcsrt_dif_total, 0.05), (education_years, 0.05), (cbtt_indirect, 0.05)]
# Region=tha_l                                        [(vospt_silhouette, 0.95), (ft_animals, 0.95), (st_1, 0.95), (st_3, 0.95), (rocf_30min, 0.85), (diagnostic_FTD, 0.8), (ace3_fluency, 0.8), (diagnostic_CT, 0.75), (st_2, 0.7), (sex_male, 0.7), (cbtt_indirect, 0.7), (sex_female, 0.6), (cbtt_direct, 0.6), (fcsrt_l1, 0.5), (tmt_a, 0.5), (fcsrt_dif_free, 0.5), (diagnostic_AD, 0.5), (tlt_total_correct, 0.5), (ft_formal, 0.45), (fcsrt_lt, 0.45), (education_years, 0.45), (ace, 0.35), (current_age, 0.3), (rocf_3min, 0.3), (ace3_attention, 0.25), (mst_direct, 0.2), (fcsrt_dif_total, 0.2), (rocf_time, 0.15), (ace3_language, 0.15), (rocf_copy, 0.15), (mst_indirect, 0.1), (bnt, 0.1), (fcsrt_total, 0.1), (rocf_recognition, 0.1), (tmt_b, 0.1), (vospt_location, 0.05), (ace3_memory, 0.05), (sdmt, 0.05), (ace3_visuospatial, 0.05), (vospt_decision, 0.05)]
# Region=in_l                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [(diagnostic_FTD, 1.0), (st_1, 0.95), (tlt_total_correct, 0.9), (rocf_time, 0.85), (ace3_language, 0.25), (rocf_recognition, 0.25), (rocf_3min, 0.15), (ace3_fluency, 0.1), (ace, 0.1), (ace3_attention, 0.05), (fcsrt_lt, 0.05), (mst_direct, 0.05), (st_2, 0.05)]
# Region=f3o_l                                                                                                                            [(diagnostic_FTD, 1.0), (mst_direct, 0.65), (tlt_total_correct, 0.4), (cbtt_indirect, 0.35), (vospt_silhouette, 0.35), (bnt, 0.25), (st_1, 0.25), (st_2, 0.25), (rocf_copy, 0.2), (rocf_3min, 0.15), (fcsrt_l1, 0.15), (ft_animals, 0.15), (education_years, 0.1), (vospt_location, 0.1), (vospt_decision, 0.1), (tmt_a, 0.1), (diagnostic_CT, 0.1), (fcsrt_dif_free, 0.1), (ace3_memory, 0.1), (ft_formal, 0.1), (diagnostic_AD, 0.1), (cbtt_direct, 0.1), (ace3_language, 0.1), (ace3_visuospatial, 0.05), (fcsrt_dif_total, 0.05), (vospt_discrimination, 0.05), (rocf_recognition, 0.05), (sex_female, 0.05), (sex_male, 0.05), (fcsrt_total, 0.05), (rocf_time, 0.05), (ace3_fluency, 0.05), (fcsrt_lt, 0.05), (mst_indirect, 0.05)]
# Region=t3_r                                                                                                                                                                                                                                    [(ace3_language, 1.0), (rocf_30min, 1.0), (diagnostic_FTD, 0.85), (diagnostic_AD, 0.85), (current_age, 0.8), (diagnostic_CT, 0.75), (vospt_silhouette, 0.65), (rocf_copy, 0.6), (tlt_total_correct, 0.55), (fcsrt_dif_total, 0.5), (st_2, 0.5), (vospt_decision, 0.45), (tmt_a, 0.3), (ft_formal, 0.25), (tmt_b, 0.2), (bnt, 0.2), (education_years, 0.2), (sdmt, 0.15), (mst_indirect, 0.15), (fcsrt_l1, 0.1), (fcsrt_lt, 0.1), (ft_animals, 0.1), (ace3_visuospatial, 0.1), (rocf_recognition, 0.1), (ace3_fluency, 0.1), (ace3_attention, 0.05), (sex_female, 0.05), (rocf_3min, 0.05), (rocf_time, 0.05), (ace3_memory, 0.05)]
# Region=cau_l                                                                                                                                [(diagnostic_FTD, 0.95), (rocf_recognition, 0.9), (st_3, 0.6), (education_years, 0.55), (ace3_language, 0.45), (vospt_location, 0.4), (current_age, 0.35), (ft_animals, 0.25), (diagnostic_AD, 0.25), (ace3_fluency, 0.25), (st_2, 0.25), (rocf_30min, 0.2), (ft_formal, 0.2), (ace3_memory, 0.2), (diagnostic_CT, 0.15), (sex_female, 0.15), (rocf_copy, 0.15), (vospt_decision, 0.15), (fcsrt_dif_total, 0.15), (tmt_a, 0.1), (cbtt_direct, 0.1), (ace3_attention, 0.1), (fcsrt_total, 0.1), (rocf_time, 0.05), (sdmt, 0.05), (tlt_total_correct, 0.05), (ace3_visuospatial, 0.05), (rocf_3min, 0.05), (sex_male, 0.05), (fcsrt_dif_free, 0.05), (st_1, 0.05), (fcsrt_lt, 0.05), (fcsrt_l1, 0.05), (bnt, 0.05), (mst_direct, 0.05)]
# Region=o2_l                                                                                                                                               [(vospt_discrimination, 1.0), (mst_direct, 1.0), (fcsrt_l1, 0.95), (diagnostic_FTD, 0.9), (cbtt_direct, 0.85), (fcsrt_dif_total, 0.85), (vospt_location, 0.75), (rocf_recognition, 0.7), (st_2, 0.55), (rocf_3min, 0.45), (ace3_visuospatial, 0.4), (st_1, 0.4), (st_3, 0.4), (diagnostic_AD, 0.4), (diagnostic_CT, 0.4), (vospt_decision, 0.25), (rocf_30min, 0.2), (cbtt_indirect, 0.2), (ace3_memory, 0.15), (mst_indirect, 0.15), (sex_male, 0.15), (ace, 0.15), (sex_female, 0.15), (tmt_b, 0.15), (fcsrt_lt, 0.15), (fcsrt_dif_free, 0.15), (tmt_a, 0.15), (fcsrt_total, 0.1), (ft_formal, 0.1), (ft_animals, 0.1), (education_years, 0.05), (ace3_attention, 0.05), (rocf_copy, 0.05), (vospt_silhouette, 0.05)]
# Region=fusi_l        [(vospt_discrimination, 0.95), (diagnostic_FTD, 0.9), (mst_indirect, 0.85), (ft_animals, 0.85), (mst_direct, 0.85), (rocf_recognition, 0.8), (bnt, 0.8), (fcsrt_dif_total, 0.8), (education_years, 0.75), (rocf_3min, 0.75), (ace3_language, 0.6), (sdmt, 0.6), (rocf_30min, 0.6), (ace3_visuospatial, 0.6), (cbtt_indirect, 0.6), (diagnostic_AD, 0.6), (vospt_decision, 0.55), (fcsrt_l1, 0.55), (fcsrt_lt, 0.55), (ace, 0.55), (vospt_location, 0.55), (st_2, 0.55), (ace3_fluency, 0.55), (sex_male, 0.5), (fcsrt_total, 0.5), (st_1, 0.5), (sex_female, 0.5), (current_age, 0.45), (diagnostic_CT, 0.45), (ace3_attention, 0.35), (rocf_copy, 0.35), (cbtt_direct, 0.3), (ft_formal, 0.3), (tlt_total_correct, 0.3), (rocf_time, 0.25), (st_3, 0.2), (ace3_memory, 0.2), (tmt_b, 0.2), (tmt_a, 0.15), (fcsrt_dif_free, 0.15), (vospt_silhouette, 0.05)]
# Region=put_l                                                                                                                                                                                          [(diagnostic_FTD, 1.0), (rocf_recognition, 0.85), (st_2, 0.6), (education_years, 0.5), (ace3_language, 0.45), (sex_female, 0.4), (vospt_decision, 0.4), (rocf_3min, 0.35), (rocf_30min, 0.35), (ace3_memory, 0.3), (tlt_total_correct, 0.3), (current_age, 0.25), (fcsrt_l1, 0.25), (sex_male, 0.2), (st_3, 0.2), (diagnostic_AD, 0.2), (rocf_time, 0.15), (fcsrt_total, 0.1), (diagnostic_CT, 0.1), (rocf_copy, 0.05), (ft_animals, 0.05), (ace, 0.05), (ace3_visuospatial, 0.05), (bnt, 0.05), (fcsrt_lt, 0.05), (fcsrt_dif_free, 0.05), (st_1, 0.05), (cbtt_direct, 0.05), (cbtt_indirect, 0.05), (ace3_fluency, 0.05), (fcsrt_dif_total, 0.05), (ace3_attention, 0.05)]
# Region=ag_l                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [(st_3, 1.0), (diagnostic_AD, 0.95), (education_years, 0.85), (tmt_b, 0.6), (tmt_a, 0.5), (rocf_recognition, 0.4), (sex_male, 0.25), (st_1, 0.2), (sex_female, 0.15), (diagnostic_CT, 0.1), (st_2, 0.05), (vospt_decision, 0.05), (mst_direct, 0.05), (rocf_time, 0.05), (fcsrt_l1, 0.05), (current_age, 0.05), (ace3_visuospatial, 0.05), (bnt, 0.05), (ace3_memory, 0.05), (ace3_fluency, 0.05)]
# ...
# Region=hes_l                                                                                                                                                                                                                        [(tmt_b, 1.0), (education_years, 1.0), (ace, 0.9), (fcsrt_dif_total, 0.85), (diagnostic_FTD, 0.8), (rocf_recognition, 0.8), (vospt_silhouette, 0.75), (diagnostic_CT, 0.6), (ace3_language, 0.35), (ft_animals, 0.3), (rocf_time, 0.25), (ace3_visuospatial, 0.25), (diagnostic_AD, 0.2), (rocf_copy, 0.15), (ace3_attention, 0.15), (bnt, 0.15), (sdmt, 0.1), (tlt_total_correct, 0.1), (fcsrt_total, 0.1), (fcsrt_lt, 0.1), (ace3_fluency, 0.1), (current_age, 0.1), (st_1, 0.05), (fcsrt_l1, 0.05), (cbtt_indirect, 0.05), (st_3, 0.05), (st_2, 0.05), (rocf_3min, 0.05), (fcsrt_dif_free, 0.05), (cbtt_direct, 0.05), (rocf_30min, 0.05)]
# Region=f1m_r                                                                                                        [(education_years, 0.85), (diagnostic_FTD, 0.8), (current_age, 0.6), (diagnostic_AD, 0.5), (fcsrt_dif_free, 0.45), (cbtt_indirect, 0.4), (vospt_silhouette, 0.35), (rocf_30min, 0.35), (diagnostic_CT, 0.3), (ace3_visuospatial, 0.3), (bnt, 0.3), (tmt_b, 0.25), (ft_animals, 0.2), (mst_indirect, 0.2), (sdmt, 0.2), (rocf_recognition, 0.2), (tmt_a, 0.2), (st_3, 0.2), (cbtt_direct, 0.15), (vospt_discrimination, 0.15), (ace3_language, 0.15), (st_2, 0.15), (rocf_copy, 0.15), (ace, 0.15), (tlt_total_correct, 0.15), (ace3_attention, 0.15), (st_1, 0.1), (ace3_fluency, 0.1), (ace3_memory, 0.1), (vospt_decision, 0.1), (fcsrt_total, 0.05), (ft_formal, 0.05), (rocf_time, 0.05), (mst_direct, 0.05), (rocf_3min, 0.05), (fcsrt_dif_total, 0.05)]
# Region=ro_l       [(education_years, 0.95), (ace3_language, 0.85), (ace3_fluency, 0.75), (fcsrt_dif_free, 0.7), (ace3_memory, 0.65), (vospt_silhouette, 0.65), (ft_animals, 0.55), (rocf_30min, 0.5), (tlt_total_correct, 0.45), (bnt, 0.45), (sex_male, 0.45), (tmt_b, 0.4), (fcsrt_total, 0.4), (ace3_visuospatial, 0.4), (ace, 0.4), (vospt_location, 0.35), (sex_female, 0.35), (rocf_recognition, 0.35), (tmt_a, 0.35), (fcsrt_l1, 0.3), (rocf_copy, 0.3), (cbtt_indirect, 0.3), (diagnostic_CT, 0.3), (vospt_discrimination, 0.25), (sdmt, 0.25), (fcsrt_dif_total, 0.25), (current_age, 0.25), (diagnostic_AD, 0.2), (rocf_3min, 0.2), (ace3_attention, 0.2), (mst_indirect, 0.15), (diagnostic_FTD, 0.15), (ft_formal, 0.15), (st_2, 0.15), (rocf_time, 0.15), (vospt_decision, 0.15), (fcsrt_lt, 0.15), (st_3, 0.1), (cbtt_direct, 0.1), (st_1, 0.1), (mst_direct, 0.1)]
# Region=p1_r                                                                                                                                                                                                                                     [(rocf_copy, 0.9), (fcsrt_dif_free, 0.75), (education_years, 0.75), (ace3_fluency, 0.65), (diagnostic_AD, 0.65), (fcsrt_lt, 0.55), (rocf_30min, 0.4), (rocf_3min, 0.4), (cbtt_direct, 0.35), (ft_animals, 0.3), (diagnostic_CT, 0.3), (current_age, 0.25), (ace, 0.2), (fcsrt_dif_total, 0.2), (ace3_visuospatial, 0.2), (fcsrt_total, 0.15), (rocf_recognition, 0.15), (ft_formal, 0.15), (tlt_total_correct, 0.15), (bnt, 0.15), (st_2, 0.15), (fcsrt_l1, 0.15), (sdmt, 0.1), (mst_indirect, 0.1), (vospt_location, 0.1), (st_1, 0.05), (vospt_decision, 0.05), (vospt_silhouette, 0.05), (st_3, 0.05), (diagnostic_FTD, 0.05)]
# Region=t1_l                                                                                                                                                                                                                        [(st_3, 0.65), (ace3_fluency, 0.55), (current_age, 0.55), (tmt_b, 0.55), (diagnostic_CT, 0.55), (fcsrt_total, 0.5), (vospt_silhouette, 0.45), (mst_indirect, 0.4), (ace3_attention, 0.35), (ft_formal, 0.3), (education_years, 0.25), (fcsrt_l1, 0.15), (fcsrt_dif_free, 0.15), (ace3_language, 0.15), (ft_animals, 0.15), (ace, 0.15), (cbtt_indirect, 0.1), (rocf_recognition, 0.1), (diagnostic_AD, 0.1), (fcsrt_dif_total, 0.1), (ace3_memory, 0.1), (ace3_visuospatial, 0.05), (st_1, 0.05), (diagnostic_FTD, 0.05), (st_2, 0.05), (cbtt_direct, 0.05), (tmt_a, 0.05), (vospt_decision, 0.05), (rocf_time, 0.05), (vospt_location, 0.05)]
# Region=cau_r   [(diagnostic_FTD, 1.0), (sex_male, 0.8), (sex_female, 0.75), (current_age, 0.6), (mst_direct, 0.4), (rocf_recognition, 0.35), (tlt_total_correct, 0.3), (vospt_discrimination, 0.3), (rocf_30min, 0.25), (ace3_memory, 0.25), (ace3_language, 0.25), (vospt_decision, 0.25), (fcsrt_dif_free, 0.25), (st_2, 0.25), (vospt_silhouette, 0.25), (rocf_time, 0.25), (fcsrt_total, 0.25), (ft_animals, 0.25), (tmt_b, 0.25), (ft_formal, 0.25), (fcsrt_dif_total, 0.25), (tmt_a, 0.25), (diagnostic_CT, 0.25), (st_3, 0.25), (sdmt, 0.2), (cbtt_indirect, 0.2), (fcsrt_lt, 0.2), (bnt, 0.2), (diagnostic_AD, 0.15), (rocf_3min, 0.15), (st_1, 0.15), (ace3_attention, 0.15), (mst_indirect, 0.15), (fcsrt_l1, 0.15), (vospt_location, 0.15), (ace, 0.15), (ace3_visuospatial, 0.1), (rocf_copy, 0.1), (ace3_fluency, 0.1), (cbtt_direct, 0.1), (education_years, 0.05)]
# Region=t1_r                                                                                                                                                       [(diagnostic_AD, 0.9), (rocf_30min, 0.85), (tmt_b, 0.6), (mst_indirect, 0.5), (ace3_attention, 0.45), (ft_formal, 0.35), (rocf_copy, 0.3), (cbtt_direct, 0.3), (rocf_3min, 0.3), (fcsrt_dif_free, 0.25), (fcsrt_dif_total, 0.2), (sex_male, 0.2), (cbtt_indirect, 0.2), (diagnostic_FTD, 0.2), (ace3_memory, 0.2), (ace3_visuospatial, 0.2), (st_3, 0.15), (st_2, 0.15), (fcsrt_lt, 0.15), (vospt_location, 0.15), (diagnostic_CT, 0.1), (mst_direct, 0.1), (rocf_recognition, 0.1), (ace3_fluency, 0.1), (rocf_time, 0.1), (fcsrt_l1, 0.1), (vospt_decision, 0.1), (sex_female, 0.1), (ace, 0.05), (ft_animals, 0.05), (tmt_a, 0.05), (education_years, 0.05), (sdmt, 0.05), (fcsrt_total, 0.05), (bnt, 0.05)]
# Region=f3t_r                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [(current_age, 1.0), (st_2, 0.9), (diagnostic_FTD, 0.9), (fcsrt_dif_total, 0.7), (fcsrt_dif_free, 0.2), (ft_animals, 0.1), (mst_indirect, 0.1), (bnt, 0.1), (rocf_3min, 0.1), (sdmt, 0.05), (cbtt_indirect, 0.05), (rocf_30min, 0.05), (ace3_attention, 0.05), (fcsrt_lt, 0.05), (tlt_total_correct, 0.05), (diagnostic_AD, 0.05), (st_3, 0.05), (ft_formal, 0.05), (diagnostic_CT, 0.05)]
# Region=sma_r                                                                                                                       [(tlt_total_correct, 0.95), (education_years, 0.95), (ace3_fluency, 0.95), (rocf_30min, 0.9), (diagnostic_CT, 0.85), (diagnostic_AD, 0.75), (diagnostic_FTD, 0.65), (ace3_language, 0.6), (st_1, 0.6), (ace3_visuospatial, 0.6), (fcsrt_lt, 0.55), (st_3, 0.5), (ace3_memory, 0.5), (vospt_silhouette, 0.5), (mst_direct, 0.5), (ft_formal, 0.45), (tmt_b, 0.45), (rocf_recognition, 0.4), (tmt_a, 0.4), (ace3_attention, 0.4), (bnt, 0.35), (st_2, 0.35), (ft_animals, 0.3), (rocf_copy, 0.25), (ace, 0.25), (mst_indirect, 0.25), (rocf_time, 0.25), (fcsrt_l1, 0.25), (rocf_3min, 0.15), (sdmt, 0.15), (vospt_location, 0.1), (cbtt_indirect, 0.1), (current_age, 0.1), (fcsrt_dif_total, 0.1), (vospt_decision, 0.1), (fcsrt_total, 0.05)]
# Region=pcin_r                         [(rocf_time, 0.95), (rocf_3min, 0.9), (diagnostic_AD, 0.85), (rocf_recognition, 0.85), (sex_female, 0.6), (diagnostic_CT, 0.6), (vospt_decision, 0.55), (diagnostic_FTD, 0.55), (ace3_language, 0.55), (vospt_discrimination, 0.55), (sex_male, 0.5), (st_3, 0.45), (fcsrt_lt, 0.4), (ace, 0.4), (vospt_location, 0.4), (st_2, 0.35), (ace3_memory, 0.25), (ace3_visuospatial, 0.25), (rocf_30min, 0.25), (st_1, 0.2), (fcsrt_total, 0.2), (ft_formal, 0.2), (bnt, 0.2), (education_years, 0.2), (ace3_fluency, 0.15), (tmt_b, 0.15), (fcsrt_dif_free, 0.1), (ace3_attention, 0.1), (cbtt_direct, 0.1), (mst_indirect, 0.1), (vospt_silhouette, 0.1), (mst_direct, 0.05), (fcsrt_l1, 0.05), (current_age, 0.05), (tmt_a, 0.05), (rocf_copy, 0.05), (tlt_total_correct, 0.05), (cbtt_indirect, 0.05), (sdmt, 0.05), (fcsrt_dif_total, 0.05)]
# Region=pcl_l                                                                                                                                                                                                                                                                        [(ace3_attention, 1.0), (mst_direct, 0.95), (fcsrt_dif_free, 0.9), (tlt_total_correct, 0.85), (current_age, 0.85), (rocf_copy, 0.7), (sdmt, 0.25), (tmt_b, 0.25), (rocf_30min, 0.25), (ft_formal, 0.2), (fcsrt_dif_total, 0.2), (vospt_silhouette, 0.15), (ace3_visuospatial, 0.15), (ace3_fluency, 0.1), (rocf_3min, 0.1), (st_1, 0.1), (rocf_time, 0.1), (diagnostic_FTD, 0.1), (ace3_language, 0.1), (tmt_a, 0.1), (cbtt_direct, 0.1), (st_3, 0.05), (mst_indirect, 0.05), (fcsrt_l1, 0.05), (diagnostic_AD, 0.05), (rocf_recognition, 0.05), (st_2, 0.05), (sex_male, 0.05), (ace, 0.05)]
# Region=phip_r                                                                                                                                                                  [(diagnostic_FTD, 0.7), (current_age, 0.6), (cbtt_indirect, 0.45), (education_years, 0.4), (fcsrt_lt, 0.4), (fcsrt_dif_total, 0.35), (bnt, 0.35), (st_2, 0.25), (sex_female, 0.25), (diagnostic_CT, 0.25), (st_1, 0.25), (mst_indirect, 0.2), (fcsrt_l1, 0.2), (sex_male, 0.2), (ace3_attention, 0.2), (mst_direct, 0.15), (ace3_language, 0.15), (sdmt, 0.15), (fcsrt_dif_free, 0.15), (ace3_visuospatial, 0.1), (rocf_copy, 0.1), (tlt_total_correct, 0.1), (ft_animals, 0.1), (ace, 0.1), (tmt_a, 0.1), (ace3_fluency, 0.1), (st_3, 0.05), (rocf_30min, 0.05), (vospt_discrimination, 0.05), (diagnostic_AD, 0.05), (ace3_memory, 0.05), (rocf_3min, 0.05), (fcsrt_total, 0.05), (tmt_b, 0.05)]
# Region=f3op_r                                                                                                                                                                              [(st_3, 0.9), (diagnostic_AD, 0.6), (diagnostic_FTD, 0.55), (rocf_30min, 0.5), (mst_direct, 0.45), (tmt_a, 0.3), (ace, 0.3), (fcsrt_dif_free, 0.3), (mst_indirect, 0.3), (st_2, 0.25), (fcsrt_total, 0.25), (ace3_language, 0.25), (rocf_copy, 0.25), (vospt_silhouette, 0.25), (fcsrt_lt, 0.2), (vospt_decision, 0.2), (bnt, 0.15), (cbtt_indirect, 0.15), (ace3_fluency, 0.15), (rocf_recognition, 0.15), (sdmt, 0.15), (tlt_total_correct, 0.15), (tmt_b, 0.15), (fcsrt_l1, 0.15), (ft_formal, 0.1), (fcsrt_dif_total, 0.1), (ace3_attention, 0.05), (ace3_memory, 0.05), (ace3_visuospatial, 0.05), (vospt_location, 0.05), (education_years, 0.05), (vospt_discrimination, 0.05)]
# Region=v1_l                                                                                                                                                                                                                                                                                                                                                                                                                                                      [(fcsrt_lt, 0.85), (vospt_discrimination, 0.85), (rocf_30min, 0.8), (st_2, 0.6), (sex_male, 0.55), (tmt_a, 0.55), (fcsrt_dif_free, 0.35), (sex_female, 0.3), (rocf_recognition, 0.25), (ace3_language, 0.1), (bnt, 0.1), (mst_indirect, 0.1), (sdmt, 0.1), (cbtt_direct, 0.1), (ace3_visuospatial, 0.1), (fcsrt_l1, 0.1), (diagnostic_CT, 0.1), (tmt_b, 0.1), (st_3, 0.1), (fcsrt_dif_total, 0.05), (ace, 0.05)]
# Region=hes_r                                                                                          [(diagnostic_FTD, 0.95), (bnt, 0.9), (st_1, 0.85), (fcsrt_lt, 0.85), (rocf_recognition, 0.7), (ace3_language, 0.55), (vospt_silhouette, 0.55), (ace3_memory, 0.5), (mst_direct, 0.5), (rocf_3min, 0.45), (sex_female, 0.45), (fcsrt_dif_free, 0.4), (sex_male, 0.4), (diagnostic_AD, 0.4), (ft_formal, 0.4), (rocf_time, 0.4), (fcsrt_l1, 0.35), (tmt_b, 0.35), (rocf_30min, 0.35), (current_age, 0.35), (cbtt_indirect, 0.35), (st_2, 0.3), (tlt_total_correct, 0.3), (vospt_discrimination, 0.25), (ace3_attention, 0.25), (education_years, 0.2), (ace, 0.2), (rocf_copy, 0.2), (ace3_visuospatial, 0.2), (tmt_a, 0.15), (st_3, 0.15), (ft_animals, 0.15), (fcsrt_dif_total, 0.15), (diagnostic_CT, 0.1), (ace3_fluency, 0.1), (mst_indirect, 0.1), (fcsrt_total, 0.05)]
# Region=post_l                                                                                                                                                                                                                  [(diagnostic_CT, 0.5), (tmt_a, 0.45), (fcsrt_l1, 0.4), (st_1, 0.4), (fcsrt_dif_free, 0.4), (current_age, 0.35), (mst_indirect, 0.3), (ace3_attention, 0.25), (cbtt_direct, 0.25), (fcsrt_lt, 0.25), (st_3, 0.2), (rocf_copy, 0.2), (fcsrt_dif_total, 0.15), (st_2, 0.15), (fcsrt_total, 0.15), (ace3_language, 0.15), (rocf_30min, 0.15), (bnt, 0.1), (mst_direct, 0.1), (vospt_decision, 0.1), (vospt_location, 0.1), (cbtt_indirect, 0.1), (sdmt, 0.1), (education_years, 0.1), (rocf_recognition, 0.05), (diagnostic_AD, 0.05), (rocf_3min, 0.05), (sex_female, 0.05), (sex_male, 0.05), (tlt_total_correct, 0.05), (tmt_b, 0.05), (ace, 0.05)]
#
#                 Avg#
# Region=o3_l    17.90
# Region=t3_l     9.90
# Region=t2_l    10.70
# Region=o3_r    27.90
# Region=amyg_r  19.50
# Region=amyg_l  15.00
# Region=f2o_r    7.35
# Region=pcl_r   10.90
# Region=t2_r    12.45
# Region=tha_l   16.95
# Region=in_l     4.75
# Region=f3o_l    5.80
# Region=t3_r    10.80
# Region=cau_l    7.55
# Region=o2_l    12.50
# Region=fusi_l  21.45
# Region=put_l    7.60
# Region=ag_l     5.50
# Region=acin_l   4.65
# Region=o1_r    22.50
# Region=f3t_l   11.50
# Region=p2_l     6.50
# Region=o2_r    11.05
# Region=ag_r     6.35
# Region=gr_r     2.55
# Region=ling_r  29.70
# Region=tha_r   15.35
# Region=f1o_l    5.60
# Region=in_r     4.95
# Region=pal_r   13.20
# Region=t1p_l   28.70
# Region=f1_l    13.50
# Region=o1_l    19.80
# Region=acin_r   3.70
# Region=put_r   11.85
# Region=f2o_l    6.95
# Region=hip_r   14.35
# Region=fusi_r  11.50
# Region=gr_l    13.15
# Region=oc_l    20.25
# Region=f1o_r    7.85
# Region=smg_r   15.10
# Region=sma_l    8.90
# Region=pre_r    9.70
# Region=p2_r    11.55
# Region=f3op_l  11.65
# Region=q_r     23.15
# Region=smg_l   12.35
# Region=f2_l    15.00
# Region=pal_l   17.55
# Region=phip_l  11.85
# Region=f3o_r    3.25
# Region=ro_r    11.20
# Region=t2p_l   27.60
# Region=pre_l    8.15
# Region=f1_r     5.80
# Region=f1m_l   11.80
# Region=t1p_r   14.75
# Region=oc_r     9.95
# Region=pq_r     5.65
# Region=f2_r    10.75
# Region=t2p_r   11.10
# Region=q_l     12.75
# Region=pcin_l  12.25
# Region=pq_l     6.00
# Region=ling_l  12.30
# Region=mcin_l   7.30
# Region=mcin_r   5.05
# Region=hip_l   15.75
# Region=p1_l     7.30
# Region=post_r  12.95
# Region=v1_r    11.35
# Region=hes_l    9.55
# Region=f1m_r    8.55
# Region=ro_l    14.20
# Region=p1_r     8.45
# Region=t1_l     6.80
# Region=cau_r   10.95
# Region=t1_r     7.75
# Region=f3t_r    4.60
# Region=sma_r   15.55
# Region=pcin_r  12.45
# Region=pcl_l    7.90
# Region=phip_r   6.75
# Region=f3op_r   7.55
# Region=v1_l     6.20
# Region=hes_r   13.85
# Region=post_l   5.80

# %% [markdown]
# Down below, we include a **heatmap indicating the frequency of each feature in predicting each region**. The regions are ordered according to the lobe they belong to. The features are ordered by nature (diagnostic features, demographic features and cognitive features -ordered themselves according to the cognitive function measured-). This makes it easier to see patterns.

# %%
matplotlib.rcParams['figure.figsize'] = (16,16)
seaborn.heatmap(map_aal,cmap='Greys',xticklabels=True,yticklabels=True)

# %% [markdown]
# #### Brodmann atlas (47 regions)

# %% [markdown]
# Down below we show the **sorted regions according to accuracy and f1 score**. In the second table, only test information is given (those regions appearing at the top are the ones with better overall models).

# %%
metrics_pct_brodmann = pandas.concat([metrics_brodmann,pct_brodmann],join='inner')
metrics_pct_brodmann
# Out:
#                         Region=b21     Region=b39     Region=b43  \
# accuracy_test        0.802+/-0.031  0.833+/-0.037  0.990+/-0.014
# accuracy_train       0.905+/-0.009  0.970+/-0.009  0.998+/-0.002
# f1_test              0.775+/-0.035  0.744+/-0.054  0.779+/-0.304
# f1_train             0.892+/-0.009  0.955+/-0.012  0.958+/-0.041
# precision_test       0.732+/-0.048  0.738+/-0.066  0.770+/-0.334
# precision_train      0.840+/-0.017  0.929+/-0.023  0.922+/-0.075
# recall_test          0.828+/-0.068  0.754+/-0.068  0.840+/-0.307
# recall_train         0.951+/-0.016  0.983+/-0.009  1.000+/-0.000
# percentage_positive          0.413          0.322          0.021
#
#                         Region=b40     Region=b20     Region=b25  \
# accuracy_test        0.772+/-0.036  0.773+/-0.031  0.931+/-0.028
# accuracy_train       0.855+/-0.015  0.895+/-0.008  0.997+/-0.002
# f1_test              0.732+/-0.038  0.725+/-0.045  0.644+/-0.130
# f1_train             0.828+/-0.015  0.875+/-0.010  0.985+/-0.008
# precision_test       0.681+/-0.050  0.680+/-0.041  0.742+/-0.189
# precision_train      0.776+/-0.025  0.814+/-0.015  0.971+/-0.016
# recall_test          0.794+/-0.053  0.783+/-0.081  0.594+/-0.144
# recall_train         0.888+/-0.014  0.946+/-0.015  1.000+/-0.000
# percentage_positive          0.392          0.386          0.105
#
#                         Region=b45     Region=b37     Region=b47  \
# accuracy_test        0.918+/-0.024  0.790+/-0.039  0.840+/-0.031
# accuracy_train       0.998+/-0.002  0.890+/-0.010  0.878+/-0.009
# f1_test              0.633+/-0.113  0.699+/-0.049  0.638+/-0.057
# f1_train             0.991+/-0.007  0.841+/-0.013  0.722+/-0.017
# precision_test       0.771+/-0.160  0.621+/-0.060  0.599+/-0.081
# precision_train      0.982+/-0.014  0.746+/-0.019  0.668+/-0.027
# recall_test          0.563+/-0.146  0.808+/-0.076  0.695+/-0.086
# recall_train         1.000+/-0.000  0.962+/-0.011  0.786+/-0.023
# percentage_positive           0.13          0.301          0.202
#
#                          Region=b7     Region=b19     Region=b18  \
# accuracy_test        0.789+/-0.039  0.778+/-0.045  0.866+/-0.036
# accuracy_train       0.912+/-0.010  0.813+/-0.014  0.976+/-0.007
# f1_test              0.677+/-0.055  0.685+/-0.053  0.616+/-0.096
# f1_train             0.867+/-0.014  0.731+/-0.015  0.932+/-0.018
# precision_test       0.637+/-0.061  0.606+/-0.068  0.587+/-0.109
# precision_train      0.801+/-0.021  0.647+/-0.023  0.873+/-0.031
# recall_test          0.727+/-0.076  0.796+/-0.066  0.658+/-0.115
# recall_train         0.945+/-0.014  0.840+/-0.016  1.000+/-0.000
# percentage_positive          0.304          0.301          0.163
#
#                         Region=b32     Region=b22     Region=b38  \
# accuracy_test        0.871+/-0.025  0.757+/-0.041  0.796+/-0.038
# accuracy_train       0.884+/-0.007  0.859+/-0.015  0.833+/-0.014
# f1_test              0.582+/-0.080  0.674+/-0.050  0.642+/-0.067
# f1_train             0.633+/-0.022  0.815+/-0.018  0.706+/-0.022
# precision_test       0.555+/-0.082  0.622+/-0.070  0.620+/-0.069
# precision_train      0.586+/-0.023  0.732+/-0.025  0.677+/-0.032
# recall_test          0.631+/-0.126  0.748+/-0.087  0.678+/-0.108
# recall_train         0.688+/-0.034  0.920+/-0.020  0.740+/-0.035
# percentage_positive          0.145          0.337          0.271
#
#                         Region=b36     Region=b17     Region=b13  \
# accuracy_test        0.890+/-0.020  0.951+/-0.018  0.821+/-0.039
# accuracy_train       0.989+/-0.005  0.974+/-0.005  0.833+/-0.011
# f1_test              0.533+/-0.077  0.521+/-0.139  0.603+/-0.074
# f1_train             0.956+/-0.020  0.749+/-0.037  0.630+/-0.019
# precision_test       0.543+/-0.124  0.446+/-0.136  0.513+/-0.071
# precision_train      0.916+/-0.036  0.601+/-0.048  0.532+/-0.022
# recall_test          0.554+/-0.128  0.700+/-0.249  0.738+/-0.099
# recall_train         1.000+/-0.000  1.000+/-0.000  0.775+/-0.028
# percentage_positive          0.114          0.039          0.184
#
#                         Region=b28     Region=b34     Region=b27  \
# accuracy_test        0.912+/-0.026  0.959+/-0.022  0.995+/-0.009
# accuracy_train       0.982+/-0.007  0.980+/-0.004  0.997+/-0.002
# f1_test              0.552+/-0.132  0.558+/-0.189  0.707+/-0.390
# f1_train             0.915+/-0.032  0.772+/-0.042  0.883+/-0.064
# precision_test       0.566+/-0.162  0.495+/-0.247  0.667+/-0.406
# precision_train      0.845+/-0.055  0.631+/-0.056  0.797+/-0.109
# recall_test          0.580+/-0.197  0.760+/-0.275  0.800+/-0.400
# recall_train         1.000+/-0.000  1.000+/-0.000  1.000+/-0.000
# percentage_positive          0.096          0.033          0.012
#
#                          Region=b6      Region=b2     Region=b29  \
# accuracy_test        0.758+/-0.043  0.903+/-0.027  0.996+/-0.010
# accuracy_train       0.847+/-0.012  0.992+/-0.003  1.000+/-0.000
# f1_test              0.644+/-0.063  0.541+/-0.126  0.720+/-0.426
# f1_train             0.775+/-0.015  0.969+/-0.011  1.000+/-0.000
# precision_test       0.576+/-0.056  0.637+/-0.173  0.707+/-0.435
# precision_train      0.693+/-0.022  0.940+/-0.021  1.000+/-0.000
# recall_test          0.736+/-0.100  0.501+/-0.162  0.760+/-0.427
# recall_train         0.879+/-0.018  1.000+/-0.000  1.000+/-0.000
# percentage_positive          0.298          0.117          0.012
#
#                         Region=b44     Region=b42     Region=b10  \
# accuracy_test        0.910+/-0.031  0.897+/-0.024  0.754+/-0.045
# accuracy_train       0.933+/-0.009  0.971+/-0.006  0.789+/-0.011
# f1_test              0.513+/-0.113  0.512+/-0.110  0.618+/-0.055
# f1_train             0.632+/-0.035  0.868+/-0.022  0.671+/-0.014
# precision_test       0.436+/-0.130  0.483+/-0.108  0.531+/-0.061
# precision_train      0.510+/-0.038  0.768+/-0.034  0.572+/-0.016
# recall_test          0.668+/-0.157  0.574+/-0.172  0.745+/-0.075
# recall_train         0.833+/-0.037  1.000+/-0.000  0.814+/-0.022
# percentage_positive          0.069          0.096          0.265
#
#                         Region=b46     Region=b31     Region=b11  \
# accuracy_test        0.831+/-0.034  0.766+/-0.040  0.784+/-0.043
# accuracy_train       0.912+/-0.014  0.850+/-0.009  0.818+/-0.014
# f1_test              0.546+/-0.077  0.596+/-0.058  0.586+/-0.066
# f1_train             0.766+/-0.028  0.737+/-0.013  0.643+/-0.022
# precision_test       0.474+/-0.079  0.493+/-0.053  0.457+/-0.062
# precision_train      0.649+/-0.039  0.610+/-0.016  0.503+/-0.022
# recall_test          0.663+/-0.129  0.765+/-0.105  0.827+/-0.107
# recall_train         0.935+/-0.021  0.931+/-0.014  0.890+/-0.029
# percentage_positive          0.154          0.226          0.184
#
#                          Region=b9      Region=b8     Region=b35  \
# accuracy_test        0.756+/-0.042  0.759+/-0.045  0.929+/-0.025
# accuracy_train       0.802+/-0.019  0.870+/-0.015  0.986+/-0.005
# f1_test              0.607+/-0.061  0.603+/-0.058  0.500+/-0.152
# f1_train             0.674+/-0.024  0.781+/-0.021  0.911+/-0.029
# precision_test       0.543+/-0.064  0.525+/-0.072  0.529+/-0.197
# precision_train      0.610+/-0.034  0.681+/-0.029  0.838+/-0.051
# recall_test          0.696+/-0.089  0.719+/-0.078  0.522+/-0.198
# recall_train         0.756+/-0.034  0.917+/-0.018  1.000+/-0.000
# percentage_positive          0.271          0.253          0.069
#
#                         Region=b23     Region=b24      Region=b5  \
# accuracy_test        0.892+/-0.032  0.816+/-0.036  0.905+/-0.027
# accuracy_train       0.948+/-0.011  0.820+/-0.011  0.980+/-0.006
# f1_test              0.479+/-0.103  0.485+/-0.082  0.442+/-0.141
# f1_train             0.740+/-0.044  0.502+/-0.020  0.892+/-0.030
# precision_test       0.385+/-0.111  0.419+/-0.075  0.457+/-0.173
# precision_train      0.589+/-0.056  0.425+/-0.021  0.807+/-0.049
# recall_test          0.670+/-0.138  0.591+/-0.122  0.480+/-0.201
# recall_train         1.000+/-0.000  0.615+/-0.032  1.000+/-0.000
# percentage_positive          0.072          0.148          0.081
#
#                          Region=b4      Region=b3      Region=b1  \
# accuracy_test        0.931+/-0.023  0.925+/-0.035  0.940+/-0.028
# accuracy_train       0.972+/-0.007  0.989+/-0.006  0.973+/-0.006
# f1_test              0.432+/-0.172  0.476+/-0.209  0.459+/-0.223
# f1_train             0.763+/-0.048  0.924+/-0.037  0.749+/-0.046
# precision_test       0.357+/-0.149  0.491+/-0.258  0.365+/-0.210
# precision_train      0.620+/-0.064  0.861+/-0.064  0.601+/-0.059
# recall_test          0.587+/-0.271  0.514+/-0.254  0.693+/-0.319
# recall_train         1.000+/-0.000  1.000+/-0.000  1.000+/-0.000
# percentage_positive          0.045          0.066          0.039
#
#                         Region=b41     Region=b33     Region=b30
# accuracy_test        0.884+/-0.027  0.999+/-0.004  0.773+/-0.050
# accuracy_train       0.938+/-0.010  1.000+/-0.001  0.830+/-0.022
# f1_test              0.373+/-0.099  0.600+/-0.490  0.355+/-0.061
# f1_train             0.624+/-0.037  0.986+/-0.047  0.490+/-0.037
# precision_test       0.268+/-0.086  0.600+/-0.490  0.249+/-0.059
# precision_train      0.454+/-0.040  0.977+/-0.080  0.342+/-0.036
# recall_test          0.680+/-0.214  0.600+/-0.490  0.661+/-0.146
# recall_train         1.000+/-0.000  1.000+/-0.000  0.869+/-0.040
# percentage_positive          0.051          0.009          0.093

# %%
metrics_pct_brodmann.transpose()[['accuracy_test','f1_test','precision_test','recall_test','percentage_positive']]
# Out:
#             accuracy_test        f1_test precision_test    recall_test  \
# Region=b21  0.802+/-0.031  0.775+/-0.035  0.732+/-0.048  0.828+/-0.068
# Region=b39  0.833+/-0.037  0.744+/-0.054  0.738+/-0.066  0.754+/-0.068
# Region=b43  0.990+/-0.014  0.779+/-0.304  0.770+/-0.334  0.840+/-0.307
# Region=b40  0.772+/-0.036  0.732+/-0.038  0.681+/-0.050  0.794+/-0.053
# Region=b20  0.773+/-0.031  0.725+/-0.045  0.680+/-0.041  0.783+/-0.081
# Region=b25  0.931+/-0.028  0.644+/-0.130  0.742+/-0.189  0.594+/-0.144
# Region=b45  0.918+/-0.024  0.633+/-0.113  0.771+/-0.160  0.563+/-0.146
# Region=b37  0.790+/-0.039  0.699+/-0.049  0.621+/-0.060  0.808+/-0.076
# Region=b47  0.840+/-0.031  0.638+/-0.057  0.599+/-0.081  0.695+/-0.086
# Region=b7   0.789+/-0.039  0.677+/-0.055  0.637+/-0.061  0.727+/-0.076
# Region=b19  0.778+/-0.045  0.685+/-0.053  0.606+/-0.068  0.796+/-0.066
# Region=b18  0.866+/-0.036  0.616+/-0.096  0.587+/-0.109  0.658+/-0.115
# Region=b32  0.871+/-0.025  0.582+/-0.080  0.555+/-0.082  0.631+/-0.126
# Region=b22  0.757+/-0.041  0.674+/-0.050  0.622+/-0.070  0.748+/-0.087
# Region=b38  0.796+/-0.038  0.642+/-0.067  0.620+/-0.069  0.678+/-0.108
# Region=b36  0.890+/-0.020  0.533+/-0.077  0.543+/-0.124  0.554+/-0.128
# Region=b17  0.951+/-0.018  0.521+/-0.139  0.446+/-0.136  0.700+/-0.249
# Region=b13  0.821+/-0.039  0.603+/-0.074  0.513+/-0.071  0.738+/-0.099
# Region=b28  0.912+/-0.026  0.552+/-0.132  0.566+/-0.162  0.580+/-0.197
# Region=b34  0.959+/-0.022  0.558+/-0.189  0.495+/-0.247  0.760+/-0.275
# Region=b27  0.995+/-0.009  0.707+/-0.390  0.667+/-0.406  0.800+/-0.400
# Region=b6   0.758+/-0.043  0.644+/-0.063  0.576+/-0.056  0.736+/-0.100
# Region=b2   0.903+/-0.027  0.541+/-0.126  0.637+/-0.173  0.501+/-0.162
# Region=b29  0.996+/-0.010  0.720+/-0.426  0.707+/-0.435  0.760+/-0.427
# Region=b44  0.910+/-0.031  0.513+/-0.113  0.436+/-0.130  0.668+/-0.157
# Region=b42  0.897+/-0.024  0.512+/-0.110  0.483+/-0.108  0.574+/-0.172
# Region=b10  0.754+/-0.045  0.618+/-0.055  0.531+/-0.061  0.745+/-0.075
# Region=b46  0.831+/-0.034  0.546+/-0.077  0.474+/-0.079  0.663+/-0.129
# Region=b31  0.766+/-0.040  0.596+/-0.058  0.493+/-0.053  0.765+/-0.105
# Region=b11  0.784+/-0.043  0.586+/-0.066  0.457+/-0.062  0.827+/-0.107
# Region=b9   0.756+/-0.042  0.607+/-0.061  0.543+/-0.064  0.696+/-0.089
# Region=b8   0.759+/-0.045  0.603+/-0.058  0.525+/-0.072  0.719+/-0.078
# Region=b35  0.929+/-0.025  0.500+/-0.152  0.529+/-0.197  0.522+/-0.198
# Region=b23  0.892+/-0.032  0.479+/-0.103  0.385+/-0.111  0.670+/-0.138
# Region=b24  0.816+/-0.036  0.485+/-0.082  0.419+/-0.075  0.591+/-0.122
# Region=b5   0.905+/-0.027  0.442+/-0.141  0.457+/-0.173  0.480+/-0.201
# Region=b4   0.931+/-0.023  0.432+/-0.172  0.357+/-0.149  0.587+/-0.271
# Region=b3   0.925+/-0.035  0.476+/-0.209  0.491+/-0.258  0.514+/-0.254
# Region=b1   0.940+/-0.028  0.459+/-0.223  0.365+/-0.210  0.693+/-0.319
# Region=b41  0.884+/-0.027  0.373+/-0.099  0.268+/-0.086  0.680+/-0.214
# Region=b33  0.999+/-0.004  0.600+/-0.490  0.600+/-0.490  0.600+/-0.490
# Region=b30  0.773+/-0.050  0.355+/-0.061  0.249+/-0.059  0.661+/-0.146
#
#            percentage_positive
# Region=b21               0.413
# Region=b39               0.322
# Region=b43               0.021
# Region=b40               0.392
# Region=b20               0.386
# Region=b25               0.105
# Region=b45                0.13
# Region=b37               0.301
# Region=b47               0.202
# Region=b7                0.304
# Region=b19               0.301
# Region=b18               0.163
# Region=b32               0.145
# Region=b22               0.337
# Region=b38               0.271
# Region=b36               0.114
# Region=b17               0.039
# Region=b13               0.184
# Region=b28               0.096
# Region=b34               0.033
# Region=b27               0.012
# Region=b6                0.298
# Region=b2                0.117
# Region=b29               0.012
# Region=b44               0.069
# Region=b42               0.096
# Region=b10               0.265
# Region=b46               0.154
# Region=b31               0.226
# Region=b11               0.184
# Region=b9                0.271
# Region=b8                0.253
# Region=b35               0.069
# Region=b23               0.072
# Region=b24               0.148
# Region=b5                0.081
# Region=b4                0.045
# Region=b3                0.066
# Region=b1                0.039
# Region=b41               0.051
# Region=b33               0.009
# Region=b30               0.093

# %% [markdown]
# Down below, we include the **selected features for the best model and the most common features in all the models**.

# %%
features_brodmann
# Out:
#                                                                                                                                                                                                                                                                                                                                 Features best model  \
# Region=b21                                                                                                                                                                                         [ace3_visuospatial, fcsrt_dif_free, st_1, rocf_time, fcsrt_dif_total, diagnostic_CT, ft_animals, fcsrt_lt, rocf_30min, fcsrt_l1, diagnostic_FTD]
# Region=b39                                                                                            [st_2, fcsrt_lt, tmt_b, ace3_memory, fcsrt_dif_free, vospt_location, diagnostic_CT, ace3_visuospatial, st_3, ft_animals, vospt_silhouette, fcsrt_total, current_age, diagnostic_AD, sex_male, mst_direct, tmt_a, rocf_recognition, ft_formal]
# Region=b43                                                                                                                         [ace3_visuospatial, st_1, fcsrt_l1, mst_direct, fcsrt_dif_free, bnt, ace, sex_male, diagnostic_CT, diagnostic_FTD, vospt_location, vospt_silhouette, st_2, cbtt_indirect, sex_female, education_years, fcsrt_lt]
# Region=b40                                                                                                                                                                                                                    [sex_male, diagnostic_CT, st_1, ace3_visuospatial, mst_indirect, rocf_recognition, current_age, diagnostic_AD, tmt_b]
# Region=b20                                                                                                                                                                                   [rocf_3min, vospt_decision, st_1, st_2, fcsrt_l1, rocf_30min, fcsrt_lt, rocf_recognition, education_years, ft_animals, fcsrt_dif_total, diagnostic_CT]
# Region=b25                                                            [vospt_discrimination, cbtt_indirect, diagnostic_FTD, tlt_total_correct, fcsrt_dif_free, tmt_b, fcsrt_lt, tmt_a, bnt, fcsrt_l1, vospt_decision, rocf_time, fcsrt_total, rocf_recognition, st_2, diagnostic_AD, current_age, ace3_language, education_years, vospt_silhouette]
# Region=b45  [rocf_copy, cbtt_indirect, ft_animals, tmt_b, diagnostic_CT, education_years, bnt, ace3_language, ace3_memory, diagnostic_FTD, mst_indirect, fcsrt_dif_free, mst_direct, rocf_30min, vospt_silhouette, rocf_time, tlt_total_correct, fcsrt_lt, current_age, ace, tmt_a, st_2, st_1, cbtt_direct, fcsrt_l1, ace3_attention, fcsrt_total]
# Region=b37                                                                                                                                                                                                 [diagnostic_AD, st_1, cbtt_direct, tmt_b, ace3_visuospatial, rocf_recognition, rocf_30min, mst_indirect, fcsrt_dif_total, ace3_language]
# Region=b47                                                                                                                                                                                                                [cbtt_direct, diagnostic_FTD, fcsrt_lt, diagnostic_CT, vospt_silhouette, diagnostic_AD, ace3_language, tlt_total_correct]
# Region=b7                                                                                                                         [diagnostic_FTD, fcsrt_dif_free, cbtt_indirect, ace3_attention, cbtt_direct, vospt_silhouette, ace3_language, diagnostic_CT, rocf_copy, diagnostic_AD, mst_indirect, education_years, st_3, vospt_discrimination]
# Region=b19                                                                                                                                                                                                                                                   [rocf_3min, diagnostic_AD, ace3_language, st_2, st_3, mst_indirect, tlt_total_correct]
# Region=b18                                                                                 [sex_female, vospt_location, ft_formal, diagnostic_AD, tlt_total_correct, vospt_discrimination, sex_male, rocf_30min, st_1, rocf_time, ace3_attention, st_2, mst_direct, diagnostic_FTD, rocf_3min, st_3, rocf_recognition, ace3_fluency, cbtt_indirect]
# Region=b32                                                                                                                                                                                                                                                                           [fcsrt_dif_total, rocf_recognition, rocf_time, diagnostic_FTD]
# Region=b22                                                                                                                                                                                                                                       [mst_indirect, rocf_copy, ft_animals, diagnostic_CT, ft_formal, vospt_location, current_age, st_3]
# Region=b38                                                                                                                                                                                                                                                     [sex_female, fcsrt_l1, diagnostic_FTD, st_3, fcsrt_dif_free, sex_male, ace3_fluency]
# Region=b36                                                                   [fcsrt_total, rocf_recognition, tlt_total_correct, vospt_location, sex_female, ace3_attention, rocf_3min, ace3_fluency, st_1, ace3_language, mst_indirect, bnt, mst_direct, st_2, fcsrt_dif_free, ace3_visuospatial, diagnostic_FTD, education_years, fcsrt_l1, tmt_b]
# Region=b17                                                                                                                                                                                                        [st_3, education_years, fcsrt_dif_free, ace3_language, ace3_attention, diagnostic_FTD, fcsrt_lt, vospt_discrimination, ace, sdmt]
# Region=b13                                                                                                                                                                                                                                                                      [st_2, ace3_fluency, diagnostic_FTD, mst_direct, tlt_total_correct]
# Region=b28                                                                                                                                      [vospt_decision, diagnostic_AD, bnt, rocf_copy, rocf_30min, vospt_discrimination, current_age, ace3_language, sex_male, cbtt_direct, ft_formal, tlt_total_correct, fcsrt_dif_total, diagnostic_FTD]
# Region=b34                                                                                                                                                              [ft_formal, rocf_3min, st_3, sex_male, fcsrt_lt, sex_female, diagnostic_AD, rocf_time, st_2, st_1, rocf_30min, rocf_copy, diagnostic_CT, rocf_recognition, fcsrt_dif_total]
# Region=b27                                                                                                                                                                                                                  [vospt_silhouette, fcsrt_dif_free, fcsrt_lt, education_years, sex_male, tlt_total_correct, vospt_discrimination, tmt_b]
# Region=b6                                                                                                                                                                                                             [diagnostic_CT, diagnostic_FTD, bnt, fcsrt_dif_free, cbtt_indirect, ace3_visuospatial, fcsrt_total, mst_direct, mst_indirect]
# Region=b2                                        [rocf_recognition, ace, current_age, ace3_fluency, fcsrt_dif_free, rocf_3min, rocf_copy, bnt, fcsrt_l1, sex_male, tlt_total_correct, fcsrt_lt, st_3, cbtt_indirect, fcsrt_dif_total, vospt_silhouette, diagnostic_FTD, vospt_decision, rocf_time, vospt_location, fcsrt_total, ace3_memory, tmt_a]
# Region=b29                                                                                                                                                                                                                      [ace3_language, tlt_total_correct, fcsrt_lt, ace, rocf_3min, education_years, vospt_discrimination, bnt, ft_formal]
# Region=b44                                                                                                                                                                                                                                               [current_age, diagnostic_CT, rocf_recognition, diagnostic_FTD, ace3_language, cbtt_direct]
# Region=b42                                                                                                                                                           [rocf_recognition, bnt, diagnostic_AD, rocf_30min, tmt_b, ace3_memory, fcsrt_dif_total, rocf_time, fcsrt_dif_free, rocf_copy, ft_animals, rocf_3min, vospt_location, fcsrt_l1]
# Region=b10                                                                                                                                                                                                                                                                [rocf_copy, st_2, tlt_total_correct, fcsrt_dif_free, diagnostic_FTD, bnt]
# Region=b46                                                                                                                                                                                                        [sex_female, mst_direct, ace3_memory, ace, st_2, bnt, tlt_total_correct, fcsrt_total, current_age, ace3_language, diagnostic_FTD]
# Region=b31                                                                                                                                                                                                                                                             [sex_female, mst_direct, tmt_b, rocf_recognition, rocf_time, st_3, fcsrt_lt]
# Region=b11                                                                                                                                                                                                                                       [education_years, diagnostic_FTD, rocf_recognition, current_age, tlt_total_correct, diagnostic_AD]
# Region=b9                                                                                                                                                                                                                                                                      [mst_indirect, st_3, diagnostic_AD, mst_direct, bnt, diagnostic_FTD]
# Region=b8                                                                                                                                                                                                          [sex_male, rocf_copy, current_age, ace3_memory, tmt_b, ft_animals, sex_female, tlt_total_correct, fcsrt_total, rocf_recognition]
# Region=b35                                                                                                   [fcsrt_dif_free, st_1, education_years, rocf_3min, ace3_visuospatial, ace3_attention, current_age, sex_male, bnt, st_3, vospt_decision, sdmt, diagnostic_CT, diagnostic_AD, diagnostic_FTD, fcsrt_total, fcsrt_l1, mst_indirect, st_2]
# Region=b23                                                                                                                                                                                                     [bnt, fcsrt_lt, diagnostic_CT, fcsrt_dif_total, current_age, fcsrt_dif_free, rocf_copy, rocf_time, rocf_recognition, vospt_decision]
# Region=b24                                                                                                                                                                                                                                                                                                              [diagnostic_FTD, rocf_time]
# Region=b5                                                                                                                                                                         [rocf_copy, rocf_recognition, vospt_silhouette, ft_animals, ft_formal, vospt_discrimination, cbtt_indirect, ace3_memory, tlt_total_correct, sdmt, ace3_attention]
# Region=b4                                                                                                                                                                                                                                   [vospt_decision, rocf_copy, ace, fcsrt_dif_free, fcsrt_lt, fcsrt_l1, ft_formal, rocf_time, current_age]
# Region=b3                                                                                                                          [rocf_copy, diagnostic_FTD, cbtt_direct, rocf_3min, st_2, tmt_a, rocf_30min, diagnostic_CT, fcsrt_lt, tmt_b, current_age, ace3_attention, ace3_memory, mst_indirect, fcsrt_dif_total, vospt_decision, ft_formal]
# Region=b1                                                                                                                                                                                                                          [cbtt_indirect, st_2, bnt, ft_formal, tmt_b, ace3_memory, mst_direct, fcsrt_lt, diagnostic_CT, rocf_30min, st_3]
# Region=b41                                                                                                                                                                                                                            [ace3_language, st_1, ace3_attention, education_years, sex_male, tlt_total_correct, diagnostic_AD, rocf_copy]
# Region=b33                                                                                                                                                                                                   [st_3, tmt_b, tlt_total_correct, sex_male, ace3_attention, ace3_visuospatial, diagnostic_CT, current_age, ft_animals, st_2, rocf_3min]
# Region=b30                                                                                                                                                                                                                                                                  [rocf_30min, st_2, sex_male, rocf_3min, vospt_discrimination, fcsrt_lt]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Features all models  \
# Region=b21                                                                                                                                                                                                                                                                                      [(st_1, 0.95), (rocf_30min, 0.95), (diagnostic_CT, 0.95), (ft_animals, 0.85), (rocf_time, 0.8), (fcsrt_lt, 0.7), (fcsrt_dif_total, 0.6), (diagnostic_FTD, 0.4), (fcsrt_l1, 0.4), (ace3_visuospatial, 0.4), (fcsrt_total, 0.3), (rocf_3min, 0.25), (diagnostic_AD, 0.25), (ace3_attention, 0.2), (st_2, 0.2), (fcsrt_dif_free, 0.2), (mst_indirect, 0.15), (current_age, 0.15), (st_3, 0.1), (tlt_total_correct, 0.1), (ace3_fluency, 0.05), (cbtt_indirect, 0.05), (mst_direct, 0.05), (ft_formal, 0.05), (ace3_memory, 0.05), (cbtt_direct, 0.05), (ace3_language, 0.05)]
# Region=b39                                                                                                                                  [(rocf_recognition, 1.0), (fcsrt_lt, 1.0), (st_3, 1.0), (vospt_location, 0.95), (diagnostic_CT, 0.95), (fcsrt_total, 0.9), (diagnostic_AD, 0.85), (vospt_silhouette, 0.75), (fcsrt_l1, 0.65), (ace3_memory, 0.55), (cbtt_direct, 0.55), (sex_male, 0.55), (diagnostic_FTD, 0.5), (sex_female, 0.5), (tmt_a, 0.45), (ace3_visuospatial, 0.4), (ace, 0.4), (tmt_b, 0.35), (ace3_language, 0.35), (st_2, 0.35), (fcsrt_dif_total, 0.3), (mst_indirect, 0.25), (ace3_attention, 0.25), (ft_formal, 0.2), (fcsrt_dif_free, 0.2), (st_1, 0.2), (education_years, 0.2), (current_age, 0.2), (mst_direct, 0.2), (bnt, 0.15), (cbtt_indirect, 0.15), (ft_animals, 0.1), (ace3_fluency, 0.1), (vospt_decision, 0.05), (rocf_time, 0.05)]
# Region=b43                                                                                                                                                               [(fcsrt_lt, 0.95), (fcsrt_dif_free, 0.95), (bnt, 0.95), (vospt_silhouette, 0.85), (st_1, 0.85), (diagnostic_FTD, 0.8), (sex_female, 0.7), (sex_male, 0.7), (diagnostic_CT, 0.7), (education_years, 0.6), (ace3_memory, 0.6), (fcsrt_l1, 0.55), (diagnostic_AD, 0.5), (cbtt_indirect, 0.5), (ace3_language, 0.45), (ace, 0.45), (current_age, 0.4), (mst_direct, 0.4), (st_2, 0.4), (ace3_visuospatial, 0.35), (vospt_location, 0.35), (tmt_b, 0.3), (fcsrt_dif_total, 0.25), (rocf_copy, 0.2), (rocf_recognition, 0.2), (ft_formal, 0.15), (sdmt, 0.15), (mst_indirect, 0.15), (rocf_30min, 0.15), (rocf_time, 0.1), (st_3, 0.1), (vospt_decision, 0.05), (rocf_3min, 0.05), (fcsrt_total, 0.05)]
# Region=b40                                                                                                                                                                                                                                                                                                                              [(st_1, 1.0), (rocf_recognition, 1.0), (diagnostic_AD, 0.95), (sex_male, 0.85), (sex_female, 0.75), (mst_indirect, 0.75), (st_3, 0.7), (tmt_b, 0.6), (tlt_total_correct, 0.45), (st_2, 0.4), (ft_formal, 0.4), (diagnostic_CT, 0.3), (current_age, 0.25), (ace3_visuospatial, 0.2), (ace3_fluency, 0.2), (rocf_time, 0.15), (cbtt_indirect, 0.15), (vospt_decision, 0.15), (education_years, 0.1), (rocf_3min, 0.1), (vospt_silhouette, 0.1), (diagnostic_FTD, 0.1), (ace3_attention, 0.05), (ace, 0.05), (fcsrt_dif_total, 0.05)]
# Region=b20                                                                                [(diagnostic_CT, 0.9), (st_2, 0.7), (education_years, 0.65), (rocf_recognition, 0.55), (rocf_30min, 0.5), (fcsrt_dif_total, 0.5), (st_3, 0.35), (diagnostic_AD, 0.35), (vospt_decision, 0.35), (tlt_total_correct, 0.3), (rocf_3min, 0.3), (bnt, 0.25), (st_1, 0.25), (diagnostic_FTD, 0.2), (ace3_attention, 0.2), (fcsrt_total, 0.2), (ace3_visuospatial, 0.2), (mst_indirect, 0.15), (sdmt, 0.15), (ace3_memory, 0.15), (vospt_discrimination, 0.15), (fcsrt_lt, 0.15), (fcsrt_l1, 0.15), (rocf_time, 0.1), (tmt_b, 0.1), (ft_animals, 0.1), (vospt_silhouette, 0.1), (ft_formal, 0.1), (ace3_fluency, 0.05), (cbtt_indirect, 0.05), (sex_male, 0.05), (ace, 0.05), (fcsrt_dif_free, 0.05), (sex_female, 0.05), (mst_direct, 0.05), (current_age, 0.05), (cbtt_direct, 0.05)]
# Region=b25                                                                     [(fcsrt_dif_free, 1.0), (vospt_silhouette, 1.0), (rocf_time, 1.0), (tlt_total_correct, 0.95), (diagnostic_FTD, 0.95), (vospt_decision, 0.8), (rocf_recognition, 0.8), (ace3_language, 0.75), (tmt_a, 0.75), (education_years, 0.75), (diagnostic_AD, 0.7), (current_age, 0.65), (tmt_b, 0.6), (vospt_discrimination, 0.6), (fcsrt_lt, 0.6), (st_2, 0.6), (fcsrt_total, 0.6), (st_1, 0.55), (bnt, 0.55), (cbtt_indirect, 0.5), (fcsrt_l1, 0.5), (ace3_visuospatial, 0.4), (diagnostic_CT, 0.4), (fcsrt_dif_total, 0.4), (rocf_3min, 0.3), (cbtt_direct, 0.3), (ace, 0.3), (ft_formal, 0.25), (sdmt, 0.25), (rocf_copy, 0.25), (ace3_memory, 0.2), (ace3_attention, 0.2), (ft_animals, 0.2), (ace3_fluency, 0.2), (st_3, 0.15), (rocf_30min, 0.15), (mst_indirect, 0.05), (sex_female, 0.05)]
# Region=b45                                                                                        [(vospt_silhouette, 1.0), (current_age, 1.0), (education_years, 1.0), (tmt_a, 0.95), (diagnostic_FTD, 0.9), (ace3_language, 0.85), (fcsrt_l1, 0.8), (ace3_memory, 0.8), (st_2, 0.75), (tmt_b, 0.75), (tlt_total_correct, 0.75), (ft_animals, 0.7), (fcsrt_dif_free, 0.7), (ace, 0.7), (rocf_30min, 0.7), (st_1, 0.65), (cbtt_direct, 0.65), (rocf_time, 0.65), (rocf_copy, 0.65), (cbtt_indirect, 0.65), (mst_indirect, 0.6), (mst_direct, 0.6), (diagnostic_CT, 0.6), (rocf_3min, 0.55), (rocf_recognition, 0.5), (st_3, 0.45), (ace3_visuospatial, 0.45), (fcsrt_lt, 0.45), (bnt, 0.45), (fcsrt_total, 0.45), (diagnostic_AD, 0.4), (vospt_decision, 0.35), (ace3_attention, 0.25), (ft_formal, 0.2), (ace3_fluency, 0.15), (sdmt, 0.15), (vospt_discrimination, 0.1)]
# Region=b37                                                                                                                                                                                                                                                                             [(diagnostic_AD, 1.0), (cbtt_direct, 0.95), (tmt_b, 0.95), (ace3_language, 0.9), (st_3, 0.9), (rocf_recognition, 0.8), (mst_indirect, 0.6), (fcsrt_dif_total, 0.45), (ace3_visuospatial, 0.4), (sdmt, 0.4), (rocf_30min, 0.4), (ace3_memory, 0.3), (rocf_3min, 0.3), (fcsrt_l1, 0.25), (mst_direct, 0.2), (diagnostic_FTD, 0.2), (bnt, 0.2), (fcsrt_total, 0.15), (tlt_total_correct, 0.15), (st_2, 0.15), (ace, 0.1), (st_1, 0.1), (diagnostic_CT, 0.1), (fcsrt_lt, 0.1), (tmt_a, 0.05), (vospt_location, 0.05), (fcsrt_dif_free, 0.05), (cbtt_indirect, 0.05), (rocf_time, 0.05)]
# Region=b47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [(tlt_total_correct, 1.0), (diagnostic_FTD, 0.95), (vospt_silhouette, 0.4), (ace3_language, 0.2), (diagnostic_CT, 0.2), (diagnostic_AD, 0.2), (fcsrt_lt, 0.1), (cbtt_direct, 0.1), (ace, 0.1), (fcsrt_dif_free, 0.05), (cbtt_indirect, 0.05), (st_3, 0.05), (st_2, 0.05), (ace3_memory, 0.05)]
# Region=b7                                                         [(diagnostic_AD, 1.0), (st_3, 0.85), (rocf_copy, 0.7), (ace3_language, 0.65), (vospt_silhouette, 0.6), (education_years, 0.6), (vospt_discrimination, 0.6), (fcsrt_dif_free, 0.5), (ft_formal, 0.5), (cbtt_direct, 0.45), (st_2, 0.45), (vospt_decision, 0.45), (ace3_attention, 0.4), (mst_indirect, 0.4), (rocf_time, 0.4), (ace3_memory, 0.4), (fcsrt_total, 0.35), (fcsrt_lt, 0.3), (bnt, 0.3), (ace, 0.25), (tlt_total_correct, 0.25), (cbtt_indirect, 0.2), (diagnostic_CT, 0.2), (ace3_visuospatial, 0.2), (diagnostic_FTD, 0.15), (fcsrt_l1, 0.15), (ft_animals, 0.15), (rocf_recognition, 0.15), (st_1, 0.15), (tmt_a, 0.15), (vospt_location, 0.1), (rocf_30min, 0.1), (rocf_3min, 0.1), (fcsrt_dif_total, 0.05), (current_age, 0.05), (sdmt, 0.05), (mst_direct, 0.05), (ace3_fluency, 0.05)]
# Region=b19                                                                                                                                                                                                                                         [(diagnostic_AD, 1.0), (ace3_language, 1.0), (mst_indirect, 0.95), (tlt_total_correct, 0.95), (st_3, 0.85), (rocf_30min, 0.7), (rocf_3min, 0.7), (fcsrt_l1, 0.3), (st_2, 0.3), (tmt_a, 0.25), (ft_formal, 0.25), (ace3_visuospatial, 0.2), (fcsrt_dif_total, 0.15), (ace, 0.1), (fcsrt_dif_free, 0.1), (fcsrt_lt, 0.1), (diagnostic_FTD, 0.1), (fcsrt_total, 0.05), (rocf_time, 0.05), (cbtt_direct, 0.05), (ft_animals, 0.05), (vospt_location, 0.05), (sex_female, 0.05), (rocf_recognition, 0.05), (vospt_discrimination, 0.05), (vospt_silhouette, 0.05), (bnt, 0.05), (ace3_attention, 0.05), (current_age, 0.05)]
# Region=b18      [(ace3_attention, 1.0), (vospt_location, 1.0), (vospt_discrimination, 1.0), (mst_direct, 0.95), (rocf_3min, 0.9), (diagnostic_AD, 0.9), (rocf_recognition, 0.9), (st_1, 0.75), (sex_female, 0.7), (ace3_fluency, 0.6), (diagnostic_FTD, 0.6), (rocf_30min, 0.6), (current_age, 0.55), (tmt_b, 0.5), (tlt_total_correct, 0.5), (st_3, 0.45), (ace, 0.45), (sex_male, 0.45), (ft_formal, 0.45), (sdmt, 0.45), (rocf_copy, 0.4), (rocf_time, 0.4), (fcsrt_lt, 0.35), (ace3_language, 0.35), (cbtt_indirect, 0.3), (mst_indirect, 0.3), (fcsrt_total, 0.3), (diagnostic_CT, 0.25), (ace3_memory, 0.25), (bnt, 0.25), (ace3_visuospatial, 0.25), (education_years, 0.2), (fcsrt_dif_total, 0.2), (st_2, 0.2), (tmt_a, 0.15), (vospt_silhouette, 0.15), (vospt_decision, 0.15), (ft_animals, 0.1), (cbtt_direct, 0.1), (fcsrt_dif_free, 0.05), (fcsrt_l1, 0.05)]
# Region=b32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [(diagnostic_FTD, 1.0), (fcsrt_dif_total, 0.8), (rocf_time, 0.65), (st_3, 0.3), (st_2, 0.15), (ft_formal, 0.15), (rocf_recognition, 0.15), (ace3_fluency, 0.15), (education_years, 0.15), (tmt_a, 0.1), (rocf_30min, 0.05), (ace3_visuospatial, 0.05), (vospt_discrimination, 0.05), (ft_animals, 0.05), (fcsrt_dif_free, 0.05)]
# Region=b22                                                                                                                                                           [(rocf_copy, 1.0), (ft_formal, 0.8), (vospt_location, 0.75), (diagnostic_CT, 0.75), (st_3, 0.75), (ft_animals, 0.65), (mst_indirect, 0.5), (education_years, 0.5), (current_age, 0.4), (fcsrt_dif_total, 0.4), (ace3_language, 0.35), (tmt_b, 0.3), (tlt_total_correct, 0.25), (ace3_visuospatial, 0.25), (ace3_attention, 0.25), (rocf_30min, 0.2), (ace3_fluency, 0.2), (tmt_a, 0.2), (fcsrt_dif_free, 0.2), (rocf_3min, 0.2), (bnt, 0.2), (st_2, 0.15), (fcsrt_total, 0.15), (vospt_silhouette, 0.15), (st_1, 0.15), (sex_female, 0.1), (cbtt_indirect, 0.1), (vospt_decision, 0.1), (sex_male, 0.05), (ace, 0.05), (cbtt_direct, 0.05), (rocf_time, 0.05), (ace3_memory, 0.05), (fcsrt_lt, 0.05)]
# Region=b38                                                                                                                                                                                                  [(st_3, 0.95), (diagnostic_FTD, 0.9), (sex_female, 0.75), (sex_male, 0.75), (ace3_fluency, 0.75), (fcsrt_dif_free, 0.7), (ace3_memory, 0.65), (bnt, 0.4), (rocf_copy, 0.35), (ft_animals, 0.35), (diagnostic_AD, 0.3), (st_2, 0.3), (ace3_language, 0.25), (ft_formal, 0.25), (fcsrt_l1, 0.25), (ace, 0.25), (diagnostic_CT, 0.25), (st_1, 0.2), (cbtt_indirect, 0.2), (rocf_recognition, 0.15), (rocf_3min, 0.15), (fcsrt_total, 0.15), (fcsrt_lt, 0.1), (current_age, 0.1), (rocf_30min, 0.1), (ace3_visuospatial, 0.1), (ace3_attention, 0.05), (education_years, 0.05), (mst_indirect, 0.05), (tlt_total_correct, 0.05), (tmt_b, 0.05), (rocf_time, 0.05)]
# Region=b36                                              [(st_1, 0.95), (diagnostic_FTD, 0.95), (vospt_location, 0.9), (bnt, 0.9), (ace3_fluency, 0.85), (ace3_language, 0.85), (mst_direct, 0.85), (tmt_b, 0.85), (sex_female, 0.8), (rocf_30min, 0.75), (st_3, 0.75), (rocf_recognition, 0.6), (sex_male, 0.55), (fcsrt_lt, 0.55), (diagnostic_CT, 0.55), (tlt_total_correct, 0.5), (st_2, 0.5), (ft_animals, 0.5), (current_age, 0.45), (rocf_copy, 0.45), (mst_indirect, 0.45), (fcsrt_dif_free, 0.4), (tmt_a, 0.35), (rocf_3min, 0.35), (sdmt, 0.35), (fcsrt_dif_total, 0.3), (ft_formal, 0.25), (ace, 0.25), (diagnostic_AD, 0.25), (fcsrt_l1, 0.25), (fcsrt_total, 0.2), (education_years, 0.2), (ace3_attention, 0.15), (ace3_memory, 0.15), (ace3_visuospatial, 0.15), (cbtt_direct, 0.15), (vospt_silhouette, 0.1), (vospt_decision, 0.1), (cbtt_indirect, 0.05)]
# Region=b17                                                                                                                                                    [(vospt_discrimination, 0.95), (diagnostic_FTD, 0.9), (tmt_a, 0.8), (fcsrt_dif_free, 0.75), (ace3_fluency, 0.65), (ace3_language, 0.65), (fcsrt_lt, 0.65), (education_years, 0.6), (ace, 0.6), (fcsrt_total, 0.5), (tlt_total_correct, 0.4), (ft_animals, 0.35), (st_3, 0.35), (ft_formal, 0.35), (mst_direct, 0.3), (sdmt, 0.3), (ace3_memory, 0.3), (fcsrt_dif_total, 0.3), (rocf_30min, 0.3), (st_2, 0.25), (ace3_attention, 0.25), (diagnostic_AD, 0.2), (current_age, 0.2), (mst_indirect, 0.2), (rocf_3min, 0.2), (tmt_b, 0.1), (cbtt_direct, 0.1), (st_1, 0.1), (diagnostic_CT, 0.1), (vospt_location, 0.05), (vospt_decision, 0.05), (rocf_time, 0.05), (ace3_visuospatial, 0.05), (sex_male, 0.05)]
# Region=b13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [(diagnostic_FTD, 1.0), (mst_direct, 1.0), (tlt_total_correct, 1.0), (st_2, 0.95), (sdmt, 0.5), (ace3_fluency, 0.35), (st_1, 0.2), (ft_formal, 0.15), (ace3_visuospatial, 0.1), (vospt_location, 0.05), (cbtt_indirect, 0.05)]
# Region=b28     [(rocf_recognition, 0.95), (diagnostic_FTD, 0.9), (ace3_language, 0.85), (ace3_fluency, 0.85), (bnt, 0.8), (fcsrt_dif_total, 0.75), (current_age, 0.75), (vospt_location, 0.75), (ft_formal, 0.7), (rocf_30min, 0.65), (vospt_decision, 0.65), (tlt_total_correct, 0.6), (sex_female, 0.55), (rocf_copy, 0.55), (mst_indirect, 0.5), (tmt_b, 0.5), (diagnostic_AD, 0.5), (fcsrt_l1, 0.5), (sex_male, 0.45), (st_1, 0.45), (diagnostic_CT, 0.45), (st_3, 0.4), (fcsrt_dif_free, 0.4), (ace3_visuospatial, 0.4), (mst_direct, 0.4), (ft_animals, 0.35), (rocf_3min, 0.35), (fcsrt_total, 0.35), (ace3_memory, 0.3), (ace, 0.3), (education_years, 0.3), (tmt_a, 0.3), (st_2, 0.25), (ace3_attention, 0.25), (vospt_discrimination, 0.2), (rocf_time, 0.2), (vospt_silhouette, 0.15), (cbtt_direct, 0.1), (cbtt_indirect, 0.1), (fcsrt_lt, 0.1), (sdmt, 0.05)]
# Region=b34                                                                                                                                                                                                                                                                                                     [(ft_formal, 1.0), (st_1, 0.9), (rocf_30min, 0.9), (rocf_copy, 0.9), (rocf_3min, 0.85), (fcsrt_lt, 0.7), (diagnostic_FTD, 0.65), (tmt_b, 0.55), (fcsrt_dif_total, 0.5), (sex_male, 0.5), (ace3_attention, 0.45), (sex_female, 0.45), (rocf_time, 0.4), (st_3, 0.35), (st_2, 0.35), (diagnostic_AD, 0.3), (rocf_recognition, 0.25), (diagnostic_CT, 0.25), (tmt_a, 0.25), (ace3_memory, 0.25), (vospt_decision, 0.2), (mst_direct, 0.1), (fcsrt_total, 0.1), (ace3_fluency, 0.1), (ace, 0.1), (ace3_visuospatial, 0.1), (sdmt, 0.05), (ace3_language, 0.05)]
# Region=b27                                                                                                                                                                                                                                                                          [(fcsrt_lt, 1.0), (education_years, 1.0), (vospt_discrimination, 0.95), (sex_female, 0.7), (tlt_total_correct, 0.65), (sex_male, 0.45), (ace3_language, 0.45), (vospt_silhouette, 0.4), (ace3_memory, 0.4), (fcsrt_dif_free, 0.35), (tmt_b, 0.3), (rocf_recognition, 0.3), (diagnostic_CT, 0.25), (ace, 0.25), (rocf_time, 0.2), (fcsrt_l1, 0.2), (st_3, 0.15), (bnt, 0.15), (st_2, 0.15), (fcsrt_total, 0.15), (ace3_visuospatial, 0.1), (mst_indirect, 0.1), (ace3_attention, 0.1), (vospt_location, 0.1), (tmt_a, 0.05), (rocf_30min, 0.05), (st_1, 0.05), (fcsrt_dif_total, 0.05)]
# Region=b6                                                                             [(cbtt_indirect, 0.8), (diagnostic_FTD, 0.8), (ft_animals, 0.55), (fcsrt_lt, 0.35), (tlt_total_correct, 0.35), (bnt, 0.35), (mst_indirect, 0.35), (diagnostic_CT, 0.3), (tmt_a, 0.3), (fcsrt_total, 0.3), (fcsrt_l1, 0.3), (ace3_visuospatial, 0.25), (ace, 0.25), (fcsrt_dif_free, 0.25), (ft_formal, 0.25), (tmt_b, 0.25), (rocf_copy, 0.25), (mst_direct, 0.2), (current_age, 0.2), (sex_male, 0.2), (vospt_location, 0.2), (education_years, 0.15), (rocf_30min, 0.15), (st_2, 0.15), (sex_female, 0.15), (vospt_decision, 0.1), (ace3_attention, 0.1), (ace3_language, 0.1), (ace3_memory, 0.1), (rocf_recognition, 0.1), (vospt_silhouette, 0.1), (sdmt, 0.1), (diagnostic_AD, 0.1), (st_3, 0.05), (rocf_3min, 0.05), (ace3_fluency, 0.05), (cbtt_direct, 0.05), (st_1, 0.05)]
# Region=b2     [(rocf_recognition, 1.0), (rocf_time, 0.95), (fcsrt_dif_total, 0.9), (fcsrt_l1, 0.9), (st_3, 0.9), (fcsrt_lt, 0.85), (vospt_location, 0.85), (rocf_3min, 0.85), (rocf_copy, 0.8), (cbtt_indirect, 0.75), (tlt_total_correct, 0.75), (diagnostic_FTD, 0.7), (st_1, 0.7), (ace3_memory, 0.7), (sex_female, 0.65), (sex_male, 0.65), (diagnostic_AD, 0.65), (bnt, 0.65), (vospt_silhouette, 0.6), (current_age, 0.6), (vospt_decision, 0.55), (tmt_b, 0.5), (st_2, 0.5), (mst_direct, 0.5), (fcsrt_dif_free, 0.45), (diagnostic_CT, 0.45), (cbtt_direct, 0.45), (ace3_visuospatial, 0.45), (ace3_fluency, 0.4), (rocf_30min, 0.4), (sdmt, 0.4), (education_years, 0.35), (tmt_a, 0.35), (ace, 0.3), (ft_formal, 0.3), (mst_indirect, 0.3), (ft_animals, 0.25), (ace3_attention, 0.25), (ace3_language, 0.25), (fcsrt_total, 0.2), (vospt_discrimination, 0.05)]
# Region=b29                                                                                                                                                                                                                                                                                                                                                                                                                           [(education_years, 0.89), (tlt_total_correct, 0.84), (vospt_discrimination, 0.84), (fcsrt_lt, 0.79), (ace3_language, 0.74), (ace, 0.53), (ft_formal, 0.47), (bnt, 0.42), (rocf_30min, 0.42), (ft_animals, 0.42), (rocf_3min, 0.37), (vospt_location, 0.32), (tmt_b, 0.32), (st_2, 0.26), (fcsrt_dif_total, 0.16), (mst_indirect, 0.11), (sdmt, 0.05), (rocf_copy, 0.05), (fcsrt_dif_free, 0.05), (tmt_a, 0.05), (ace3_fluency, 0.05)]
# Region=b44                                                                                                               [(diagnostic_FTD, 0.85), (cbtt_direct, 0.75), (current_age, 0.7), (tmt_a, 0.6), (rocf_recognition, 0.55), (education_years, 0.55), (mst_indirect, 0.5), (ace3_language, 0.45), (diagnostic_AD, 0.35), (ft_animals, 0.3), (fcsrt_l1, 0.3), (ace3_memory, 0.3), (ace3_visuospatial, 0.3), (mst_direct, 0.25), (fcsrt_dif_total, 0.25), (fcsrt_total, 0.25), (rocf_30min, 0.25), (st_3, 0.25), (fcsrt_lt, 0.25), (tlt_total_correct, 0.2), (ace, 0.2), (rocf_3min, 0.2), (diagnostic_CT, 0.2), (sdmt, 0.2), (fcsrt_dif_free, 0.2), (cbtt_indirect, 0.15), (ft_formal, 0.1), (vospt_silhouette, 0.1), (ace3_fluency, 0.1), (st_2, 0.1), (ace3_attention, 0.05), (bnt, 0.05), (tmt_b, 0.05), (sex_female, 0.05), (vospt_decision, 0.05), (st_1, 0.05)]
# Region=b42                                                                                                                       [(fcsrt_dif_free, 1.0), (vospt_location, 1.0), (diagnostic_AD, 0.95), (rocf_copy, 0.9), (rocf_recognition, 0.85), (ft_animals, 0.6), (fcsrt_l1, 0.5), (fcsrt_dif_total, 0.5), (rocf_time, 0.45), (st_1, 0.45), (ace3_attention, 0.4), (mst_indirect, 0.35), (ace3_memory, 0.35), (tmt_b, 0.35), (cbtt_indirect, 0.3), (rocf_30min, 0.3), (bnt, 0.25), (ace3_fluency, 0.25), (sdmt, 0.25), (st_3, 0.2), (ace, 0.2), (ace3_visuospatial, 0.2), (tmt_a, 0.2), (cbtt_direct, 0.15), (fcsrt_lt, 0.15), (vospt_silhouette, 0.15), (st_2, 0.1), (education_years, 0.1), (diagnostic_FTD, 0.1), (vospt_decision, 0.1), (diagnostic_CT, 0.05), (ace3_language, 0.05), (sex_male, 0.05), (mst_direct, 0.05), (rocf_3min, 0.05), (sex_female, 0.05)]
# Region=b10                                                                                                                                                                                                                                                                                                                                                                                     [(tlt_total_correct, 0.95), (fcsrt_dif_free, 0.75), (rocf_copy, 0.75), (diagnostic_FTD, 0.7), (bnt, 0.65), (diagnostic_AD, 0.55), (st_2, 0.55), (diagnostic_CT, 0.5), (sex_female, 0.2), (mst_indirect, 0.15), (sex_male, 0.15), (rocf_recognition, 0.15), (fcsrt_dif_total, 0.1), (ace3_memory, 0.1), (tmt_a, 0.1), (current_age, 0.1), (ace3_fluency, 0.05), (fcsrt_l1, 0.05), (ft_animals, 0.05), (rocf_30min, 0.05), (ace3_visuospatial, 0.05), (vospt_location, 0.05)]
# Region=b46                                                                                                                                                                                           [(current_age, 0.95), (diagnostic_FTD, 0.9), (ace3_memory, 0.7), (mst_direct, 0.7), (ace, 0.65), (ft_animals, 0.65), (tlt_total_correct, 0.45), (sex_female, 0.4), (st_2, 0.4), (bnt, 0.35), (sex_male, 0.3), (fcsrt_dif_free, 0.3), (rocf_3min, 0.3), (tmt_a, 0.3), (education_years, 0.3), (ace3_language, 0.25), (cbtt_direct, 0.25), (ace3_visuospatial, 0.25), (fcsrt_total, 0.2), (fcsrt_dif_total, 0.2), (rocf_30min, 0.15), (st_3, 0.1), (diagnostic_CT, 0.1), (ace3_attention, 0.05), (rocf_recognition, 0.05), (sdmt, 0.05), (st_1, 0.05), (cbtt_indirect, 0.05), (ft_formal, 0.05), (vospt_silhouette, 0.05), (vospt_discrimination, 0.05), (tmt_b, 0.05)]
# Region=b31                                                                                                                                                                                                                                                                                                                                                          [(rocf_recognition, 1.0), (rocf_time, 0.95), (fcsrt_lt, 0.95), (mst_direct, 0.9), (sex_male, 0.55), (st_3, 0.45), (sex_female, 0.45), (tmt_b, 0.35), (fcsrt_total, 0.25), (vospt_decision, 0.25), (diagnostic_AD, 0.2), (fcsrt_dif_total, 0.15), (rocf_3min, 0.1), (fcsrt_dif_free, 0.05), (ace3_fluency, 0.05), (st_2, 0.05), (mst_indirect, 0.05), (ace, 0.05), (ft_formal, 0.05), (ft_animals, 0.05), (diagnostic_FTD, 0.05), (rocf_30min, 0.05), (ace3_visuospatial, 0.05), (ace3_language, 0.05)]
# Region=b11                                                                                                                                                                                                                                                                                                                                                            [(tlt_total_correct, 1.0), (diagnostic_FTD, 1.0), (current_age, 1.0), (rocf_recognition, 0.75), (education_years, 0.65), (diagnostic_AD, 0.4), (diagnostic_CT, 0.4), (tmt_b, 0.25), (vospt_silhouette, 0.2), (fcsrt_total, 0.15), (tmt_a, 0.1), (ace3_visuospatial, 0.1), (st_2, 0.1), (cbtt_direct, 0.05), (st_3, 0.05), (ft_animals, 0.05), (fcsrt_lt, 0.05), (ft_formal, 0.05), (cbtt_indirect, 0.05), (bnt, 0.05), (vospt_discrimination, 0.05), (fcsrt_dif_free, 0.05), (vospt_decision, 0.05)]
# Region=b9                                                                                                                                                                                                                             [(diagnostic_FTD, 0.9), (st_3, 0.6), (cbtt_indirect, 0.4), (mst_indirect, 0.3), (tlt_total_correct, 0.2), (diagnostic_CT, 0.2), (vospt_decision, 0.2), (bnt, 0.2), (education_years, 0.2), (mst_direct, 0.2), (ace3_fluency, 0.2), (sdmt, 0.15), (rocf_3min, 0.15), (fcsrt_l1, 0.15), (fcsrt_dif_free, 0.15), (ace3_language, 0.15), (ace3_memory, 0.1), (ace3_attention, 0.1), (fcsrt_total, 0.1), (rocf_copy, 0.1), (st_2, 0.1), (diagnostic_AD, 0.1), (ace3_visuospatial, 0.1), (fcsrt_lt, 0.1), (sex_male, 0.1), (rocf_recognition, 0.05), (sex_female, 0.05), (rocf_30min, 0.05), (vospt_silhouette, 0.05), (ft_animals, 0.05)]
# Region=b8                                                                                                                    [(ft_animals, 0.95), (tmt_b, 0.8), (tlt_total_correct, 0.75), (rocf_recognition, 0.75), (fcsrt_total, 0.7), (ace3_memory, 0.65), (sex_female, 0.5), (sex_male, 0.5), (current_age, 0.5), (st_2, 0.4), (vospt_location, 0.4), (rocf_copy, 0.35), (vospt_decision, 0.35), (ace3_language, 0.35), (ft_formal, 0.3), (st_3, 0.25), (rocf_time, 0.2), (fcsrt_lt, 0.2), (ace3_fluency, 0.2), (fcsrt_dif_free, 0.15), (diagnostic_CT, 0.15), (education_years, 0.15), (cbtt_indirect, 0.15), (rocf_3min, 0.1), (rocf_30min, 0.1), (ace3_attention, 0.1), (diagnostic_FTD, 0.1), (tmt_a, 0.1), (bnt, 0.1), (diagnostic_AD, 0.1), (fcsrt_dif_total, 0.1), (st_1, 0.1), (ace, 0.05), (ace3_visuospatial, 0.05), (mst_indirect, 0.05), (fcsrt_l1, 0.05)]
# Region=b35  [(diagnostic_FTD, 0.95), (bnt, 0.95), (mst_indirect, 0.9), (st_1, 0.8), (ace3_fluency, 0.75), (rocf_30min, 0.75), (vospt_decision, 0.75), (diagnostic_AD, 0.75), (rocf_3min, 0.75), (education_years, 0.7), (sex_female, 0.65), (ace3_attention, 0.65), (sex_male, 0.65), (diagnostic_CT, 0.6), (ft_formal, 0.6), (sdmt, 0.55), (st_2, 0.55), (fcsrt_dif_total, 0.5), (fcsrt_dif_free, 0.5), (rocf_copy, 0.5), (current_age, 0.5), (ace3_language, 0.45), (ace, 0.45), (mst_direct, 0.45), (rocf_recognition, 0.4), (tmt_a, 0.4), (ace3_visuospatial, 0.4), (st_3, 0.35), (fcsrt_l1, 0.35), (rocf_time, 0.35), (fcsrt_total, 0.35), (ft_animals, 0.3), (tlt_total_correct, 0.3), (cbtt_direct, 0.3), (tmt_b, 0.25), (ace3_memory, 0.2), (vospt_silhouette, 0.2), (vospt_discrimination, 0.2), (fcsrt_lt, 0.15), (vospt_location, 0.15), (cbtt_indirect, 0.05)]
# Region=b23                                                                                                                                                                                                                                                                                                                                                                                                                              [(current_age, 1.0), (bnt, 1.0), (rocf_recognition, 0.9), (tmt_a, 0.75), (fcsrt_dif_free, 0.75), (fcsrt_lt, 0.55), (sdmt, 0.45), (rocf_time, 0.4), (vospt_decision, 0.4), (fcsrt_dif_total, 0.35), (st_3, 0.3), (fcsrt_total, 0.3), (st_2, 0.25), (diagnostic_CT, 0.15), (rocf_copy, 0.15), (mst_direct, 0.15), (rocf_3min, 0.15), (ace3_visuospatial, 0.1), (ace3_attention, 0.05), (rocf_30min, 0.05), (vospt_silhouette, 0.05)]
# Region=b24                                                                                                                                                          [(diagnostic_FTD, 0.9), (education_years, 0.55), (rocf_time, 0.35), (diagnostic_AD, 0.2), (ft_animals, 0.15), (tmt_b, 0.15), (ft_formal, 0.15), (st_2, 0.15), (rocf_recognition, 0.1), (ace3_visuospatial, 0.1), (diagnostic_CT, 0.1), (cbtt_indirect, 0.1), (ace3_fluency, 0.1), (st_1, 0.1), (current_age, 0.1), (mst_indirect, 0.1), (rocf_copy, 0.05), (ace, 0.05), (rocf_3min, 0.05), (sdmt, 0.05), (tmt_a, 0.05), (ace3_memory, 0.05), (vospt_location, 0.05), (bnt, 0.05), (cbtt_direct, 0.05), (vospt_discrimination, 0.05), (rocf_30min, 0.05), (tlt_total_correct, 0.05), (ace3_attention, 0.05), (vospt_silhouette, 0.05), (fcsrt_l1, 0.05), (fcsrt_dif_free, 0.05), (ace3_language, 0.05)]
# Region=b5    [(rocf_recognition, 1.0), (tlt_total_correct, 0.9), (ace3_attention, 0.85), (rocf_copy, 0.75), (fcsrt_dif_total, 0.7), (rocf_3min, 0.65), (mst_indirect, 0.65), (current_age, 0.65), (sdmt, 0.65), (st_3, 0.6), (ft_animals, 0.6), (ace3_memory, 0.55), (fcsrt_l1, 0.55), (cbtt_indirect, 0.55), (diagnostic_FTD, 0.5), (vospt_discrimination, 0.5), (ft_formal, 0.5), (st_2, 0.45), (vospt_silhouette, 0.45), (rocf_30min, 0.45), (rocf_time, 0.4), (tmt_b, 0.4), (education_years, 0.4), (fcsrt_lt, 0.4), (fcsrt_total, 0.35), (bnt, 0.35), (ace3_fluency, 0.35), (vospt_location, 0.3), (ace, 0.3), (fcsrt_dif_free, 0.3), (ace3_visuospatial, 0.3), (ace3_language, 0.25), (tmt_a, 0.25), (vospt_decision, 0.25), (diagnostic_AD, 0.2), (diagnostic_CT, 0.15), (st_1, 0.15), (sex_female, 0.1), (mst_direct, 0.1), (sex_male, 0.05), (cbtt_direct, 0.05)]
# Region=b4                                                                                                                                                                                                    [(fcsrt_l1, 0.85), (current_age, 0.85), (st_3, 0.75), (rocf_copy, 0.7), (mst_direct, 0.65), (fcsrt_dif_free, 0.6), (ft_formal, 0.6), (vospt_decision, 0.55), (rocf_time, 0.55), (cbtt_indirect, 0.5), (ace3_attention, 0.5), (ace, 0.45), (fcsrt_lt, 0.4), (tlt_total_correct, 0.4), (mst_indirect, 0.35), (ace3_visuospatial, 0.3), (st_2, 0.25), (fcsrt_dif_total, 0.25), (ace3_fluency, 0.25), (fcsrt_total, 0.25), (diagnostic_CT, 0.2), (rocf_recognition, 0.2), (bnt, 0.2), (education_years, 0.15), (diagnostic_FTD, 0.15), (tmt_a, 0.15), (ace3_memory, 0.15), (vospt_location, 0.05), (ace3_language, 0.05), (vospt_silhouette, 0.05), (st_1, 0.05)]
# Region=b3                                                                                            [(fcsrt_lt, 1.0), (tmt_a, 0.9), (ace3_attention, 0.85), (diagnostic_FTD, 0.8), (ft_formal, 0.75), (ace3_memory, 0.7), (diagnostic_CT, 0.7), (mst_indirect, 0.7), (tmt_b, 0.65), (st_2, 0.65), (cbtt_indirect, 0.6), (bnt, 0.6), (fcsrt_dif_total, 0.6), (education_years, 0.5), (fcsrt_l1, 0.5), (rocf_30min, 0.5), (vospt_decision, 0.5), (rocf_3min, 0.45), (cbtt_direct, 0.45), (ace3_visuospatial, 0.4), (rocf_copy, 0.4), (mst_direct, 0.35), (tlt_total_correct, 0.35), (fcsrt_total, 0.35), (current_age, 0.35), (ace3_language, 0.35), (ace, 0.3), (ft_animals, 0.3), (diagnostic_AD, 0.3), (rocf_recognition, 0.25), (ace3_fluency, 0.25), (st_1, 0.25), (sdmt, 0.2), (st_3, 0.15), (fcsrt_dif_free, 0.15), (rocf_time, 0.15), (vospt_discrimination, 0.05)]
# Region=b1                                                                                                                                                                 [(vospt_location, 0.9), (ace3_memory, 0.8), (mst_direct, 0.8), (bnt, 0.8), (fcsrt_dif_free, 0.75), (rocf_recognition, 0.7), (tmt_b, 0.6), (ace3_attention, 0.6), (diagnostic_CT, 0.6), (st_3, 0.55), (fcsrt_dif_total, 0.55), (ft_formal, 0.45), (cbtt_indirect, 0.45), (rocf_30min, 0.45), (rocf_copy, 0.4), (fcsrt_lt, 0.4), (tlt_total_correct, 0.35), (st_2, 0.35), (vospt_decision, 0.35), (ace3_visuospatial, 0.3), (tmt_a, 0.3), (diagnostic_AD, 0.3), (mst_indirect, 0.3), (st_1, 0.25), (rocf_time, 0.25), (fcsrt_l1, 0.25), (cbtt_direct, 0.25), (ace3_language, 0.15), (diagnostic_FTD, 0.15), (rocf_3min, 0.1), (ace3_fluency, 0.1), (ace, 0.05), (fcsrt_total, 0.05), (sdmt, 0.05)]
# Region=b41                                                                                                                                                                                                                                                                       [(rocf_copy, 1.0), (tlt_total_correct, 1.0), (diagnostic_AD, 0.95), (st_1, 0.9), (ace3_language, 0.8), (current_age, 0.6), (ace, 0.5), (sex_male, 0.4), (st_2, 0.4), (diagnostic_CT, 0.3), (ace3_fluency, 0.25), (diagnostic_FTD, 0.25), (sex_female, 0.25), (sdmt, 0.2), (ace3_memory, 0.2), (ace3_visuospatial, 0.15), (st_3, 0.15), (ace3_attention, 0.15), (education_years, 0.15), (mst_direct, 0.15), (cbtt_indirect, 0.1), (tmt_b, 0.1), (fcsrt_dif_free, 0.1), (rocf_recognition, 0.1), (fcsrt_dif_total, 0.05), (rocf_time, 0.05), (rocf_30min, 0.05), (vospt_silhouette, 0.05)]
# Region=b33                                                                                                                                                                                                                 [(ace3_visuospatial, 0.95), (rocf_3min, 0.7), (sex_male, 0.5), (ft_animals, 0.5), (ace, 0.45), (rocf_30min, 0.4), (st_1, 0.4), (st_2, 0.35), (tlt_total_correct, 0.35), (current_age, 0.3), (rocf_recognition, 0.3), (diagnostic_CT, 0.3), (sex_female, 0.3), (tmt_b, 0.25), (fcsrt_dif_free, 0.25), (ace3_memory, 0.25), (rocf_time, 0.2), (ft_formal, 0.2), (bnt, 0.2), (vospt_discrimination, 0.2), (ace3_attention, 0.2), (ace3_language, 0.2), (fcsrt_dif_total, 0.15), (fcsrt_total, 0.1), (cbtt_indirect, 0.1), (vospt_silhouette, 0.05), (fcsrt_lt, 0.05), (ace3_fluency, 0.05), (st_3, 0.05), (cbtt_direct, 0.05), (mst_direct, 0.05)]
# Region=b30                                                                                                                                                                                                                                                                                                                   [(vospt_discrimination, 0.8), (rocf_30min, 0.75), (fcsrt_lt, 0.65), (rocf_3min, 0.45), (sex_female, 0.3), (ace3_language, 0.3), (fcsrt_total, 0.25), (ace3_visuospatial, 0.25), (education_years, 0.2), (fcsrt_dif_total, 0.2), (tlt_total_correct, 0.2), (sex_male, 0.15), (current_age, 0.15), (st_2, 0.15), (ft_formal, 0.1), (ace, 0.1), (ace3_fluency, 0.05), (diagnostic_CT, 0.05), (st_1, 0.05), (fcsrt_l1, 0.05), (fcsrt_dif_free, 0.05), (bnt, 0.05), (rocf_copy, 0.05), (cbtt_direct, 0.05), (tmt_b, 0.05), (vospt_decision, 0.05)]
#
#              Avg#
# Region=b21   9.25
# Region=b39  15.60
# Region=b43  14.90
# Region=b40   9.80
# Region=b20   8.60
# Region=b25  19.25
# Region=b45  22.30
# Region=b37  10.30
# Region=b47   3.50
# Region=b7   12.45
# Region=b19   8.60
# Region=b18  18.45
# Region=b32   3.85
# Region=b22  10.30
# Region=b38   9.95
# Region=b36  18.50
# Region=b17  11.95
# Region=b13   5.35
# Region=b28  18.90
# Region=b34  11.55
# Region=b27   9.05
# Region=b6    8.70
# Region=b2   23.05
# Region=b29   8.16
# Region=b44  10.05
# Region=b42  11.95
# Region=b10   6.75
# Region=b46   9.60
# Region=b31   7.10
# Region=b11   6.60
# Region=b9    5.50
# Region=b8   10.80
# Region=b35  20.35
# Region=b23   8.25
# Region=b24   4.25
# Region=b5   17.90
# Region=b4   11.40
# Region=b3   17.30
# Region=b1   13.70
# Region=b41   9.35
# Region=b33   8.40
# Region=b30   5.50

# %% [markdown]
# Down below, we include a **heatmap indicating the frequency of each feature in predicting each region**. The regions are ordered according to the lobe they belong to. The features are ordered by nature (diagnostic features, demographic features and cognitive features -ordered themselves according to the cognitive function measured-). This makes it easier to see patterns.

# %%
matplotlib.rcParams['figure.figsize'] = (16,8)
seaborn.heatmap(map_brodmann,cmap='Greys',xticklabels=True,yticklabels=True)

# %% [markdown]
# ### Conclusions

# %% [markdown]
# One good news is that **results improve considerably in all brain regions**. Even with such improvement, the capability to detect positive labels remains low in many cases. In addition, there is a great variability. In the neural networks approach, we saw the following trend: "for those regions where the number of positive labels is low, the models yield lower f1 scores but higher accuracies; for those regions where the number of positive labels is moderate, the models yield higher f1 scores but lower accuracies".  With this approach, the trend is not that clear. In fact, **there are regions with few positive labels that the model detect with acceptable f1 scores**. However, it is also noticeable that more unbalanced regions tend to yield results with considerable variability.

# %% [markdown]
# There is some information that could be considered in relation to those regions that are better and worst predicted (note that we have left out those with very low percentages of positive labels, since they are very difficult to categorise).

# %% [markdown]
# #### AAL atlas (90 regions)

# %% [markdown]
# The advantage of using the AAL atlas is that we can have information regarding both hemispheres. Regarding this, we can appreciate that **left sides tend to be predicted better than right sides**. In the following summary, we include the hemisphere in brackets: right (R), left (L), both (B).
#
# Within the regions that are **best predicted**, we can recognise:
#
# - Frontal lobe:
#     - **F2O (R)** (middle frontal gyrus, orbital part)
#     - **F3O (L)** (inferior frontal gyrus, orbital part)
# - Occipital lobe:
#     - **O2 (B)** (middle occipital gyrus)
#     - **O3 (B)** (inferior occipital gyrus)
# - Parietal lobe:
#     - **PCL (R)** (paracentral lobule)
#     - **AG (B)** (angular gyrus)
# - Temporal lobe:
#     - **T2 (B)** (middle temporal gyrus)
#     - **T3 (B)** (inferior temporal gyrus)
#     - **FUSI (L)** (fusiform gyrus)
#     - **AMYG (B)** (amygdala)
# - Insular lobe:
#     - **IN (L)** (insula)
# - Subcortical region:
#     - **CAU (L)** (caudate nucleus)
#     - **THA (B)** (thalamus)
#
# Within the regions that are **worst predicted**, we can recognise:
#
# - Frontal lobe:
#     - **SMA (R)** (supplementary motor area)
#     - **F1M (R)** (superior frontal gyrus, medial part)
#     - **F3OP (R)** (inferior frontal gyrus, opercular part)
#     - **F3T (R)** (inferior frontal gyrus, triangular part)
#     - **MCIN (B)** (median cingulate gyrus)
# - Parietal lobe:
#     - **PCL (L)** (paracentral lobule)
#     - **POST (B)** (postcentral gyrus)
#     - **RO (L)** (rolandic operculum)
#     - **P1 (B)** (superior parietal gyrus)
#     - **PCIN (B)** (posterior cingulate gyrus)
# - Occipital lobe:
#     - **V1 (B)** (calcarine fissure)
# - Temporal lobe:
#     - **T1 (B)** (superior temporal gyrus)
#     - **HES (B)** (heschl gyrus)
#     - **PHIP (R)** (parahippocampal gyrus)
# - Subcortical region:
#     - **CAU (R)** (caudate nucleus)
#
# One interesting thing to see that some brain regions show a strange behaviour (one side is among the best predicted regions while the other side is among the worst predicted regions). These are the following (in brackets, we indicate the hemisphere that was better predicted):
#
# - F3T (inferior frontal gyrus, triangular part) (L)
# - PCL (paracentral lobule) (R)
# - CAU (caudate nucleus) (L)

# %% [markdown]
# #### Brodmann atlas (47 regions)

# %% [markdown]
# Within the regions that are **best predicted**, we can recognise:
#
# - Frontal lobe:
#     - **B25** (ventromedial frontal cortex)
#     - **B45** (broca's area)
#     - **B47** (inferior frontal gyrus, orbital part)
# - Parietal lobe:
#     - **B7** (visuomotor coordination)
#     - **B39** (angular gyrus)
#     - **B40** (supramarginal gyrus)
#     - **B43** (primary gustatory cortex)
# - Temporal lobe:
#     - **B20** (inferior temporal gyrus)
#     - **B21** (middle temporal gyrus)
#     - **B37** (fusiform gyrus)
#
# Within the regions that are **worst predicted**, we can recognise:
#
# - Frontal lobe:
#     - **B1** (primary somatosensory cortex)
#     - **B3** (primary somatosensory cortex)
#     - **B4** (primary motor cortex)
#     - **B8** (frontal cortex)
#     - **B24** (ventral anterior cingulate cortex)
#     - **B30** (retrosplenial cortex)
# - Parietal lobe:
#     - **B5** (superior parietal cortex)
#     - **B23** (ventral posterior cingulate cortex)
# - Temporal lobe:
#     - **B35** (perirhinal cortex)
#     - **B41** (auditory cortex)

# %% [markdown]
# In all cases, **we must think about the need for a predictive model**. It could happen that the region we are trying to predict is not really important for diagnosis. This particularly needs to be considered for those regions where the percentage of positive values is very low. It is quite likely that positive labels there do not have a real meaning but are just noise. In such case, a model won't be needed. How will we know which regions are important? We need to consider Fernando's results and have a look at those regions that are detected as relevant for diagnosis.
